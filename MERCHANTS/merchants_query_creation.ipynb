# %% [markdown]
# Get some transactions
# Add plaid merchant, add website
#
# based on https://github.com/meetcleo/data-science/blob/master/transaction-enrichment/notebooks/transactions_categories/T1-24/Data_for_TM_annotations.ipynb

# %% [markdown]
# aws codeartifact get-authorization-token --domain meetcleo --domain-owner 878877078763 --query authorizationToken --output text  and it will output the token
# pip install cleodata --extra-index-url "https://aws:<the token>@meetcleo-878877078763.d.codeartifact.us-east-1.amazonaws.com/pypi/meetcleo-releases/simple/"`

# %%
import pandas as pd
from datetime import datetime
import boto3
from botocore.exceptions import ClientError
from io import StringIO
from cleodata.utils.secrets import get_secret
from cleodata.sources.sync.sync import SyncDataSource
# boto3.setup_default_session(profile_name='DataScientist-878877078763')
# redshift_source = SyncDataSource("data_exploration", use_redshift=True, redshift_cluster="cleo-production-redshift", redshift_db="cleo")

# %%
# import s3fs
# from fastparquet import ParquetFile

# %%
def read_from_s3(path):
    """Read parquet files and combine them into a single dataframe"""
    fs = s3fs.core.S3FileSystem()
    all_paths_from_s3 = fs.glob(path=f"{path}*.parquet")

    if len(all_paths_from_s3) > 0:
        s3 = s3fs.S3FileSystem()
        fp_obj = ParquetFile(
            all_paths_from_s3, open_with=s3.open
        )  # use s3fs as the filesystem
        data = fp_obj.to_pandas()
        return data
    elif len(all_paths_from_s3)==1:
        return pd.read_parquet(all_paths_from_s3[0])
    else:
        print(f"Nothing found")
        print(f"paths from a{all_paths_from_s3}")
    
def read_csv_s3(bucket, key):
    try:
        s3 = boto3.client('s3')
        obj = s3.get_object(Bucket=bucket, Key=key)
        df = pd.read_csv(obj['Body'])
        return df
    except ClientError as ex:
        if ex.response['Error']['Code'] == 'NoSuchKey':
            print("Key doesn't match. Please check the key value entered.")

# %% [markdown]
#  - **Description 1**: Text description of transactions: Internal description or processed and cleared description from external provider
#
#  - **Description 2**: Text description of transactions, original from external provider. The text returned by the financial institution to describe the transaction.
#
#  - **Additional Merchant name (original):** Merchant name of transaction from external provider
#
#  - **Original Transfer counterparty name:** Extracted from some transaction information from external provider
#
#  - **Location:** If not empty, will include information as in following example:
#
# {'lat': 28.607128, 'lon': -81.387253, 'city': 'Orlando', 'region': 'FL', 'address': '609 Lee Rd', 'country': None, 'postal_code': '32810', 'store_number': None}
#
# - **Payment channel:** The channel used to make a payment. Possible values: online, in store, other: - online: transactions that took place online. - in store: transactions that were made at a physical location. - other: transactions that relate to banks, e.g. fees or deposits.
#
# - **Payee:** name of transfer receiver -+ Payer: name of transfer sender
#
# - Google search link for “Additional Merchant name (original)”
#
# - Google search link for “Description 1”
#
# - Google search link for “Description 2”
#
# - Google search link for “Original Transfer counterparty name”
#
# - Google search link for “Description 2 and Original Transfer counterparty name”

# %%
#original query
# df = redshift_source.fetch_data( """
# with 
# presect_transactions as (
#     select 
#             tt.id,
#             tt.transaction_category_id,
#             tt.currency_code,
#             tt.amount,
#             tt.corrected_made_on, 
#             tt.made_on, 
#             tt.login_provider_additional_attributes,
#             tt.description,
#             tt.status
#     from transactions tt
#     where tt.made_on between '2024-01-20' and '2024-01-31'
#     limit 10000
# )

# select
#     tt.id,
#     tc.name as transaction_category_v1,
#     json_extract_path_text(tt.login_provider_additional_attributes, 'personal_finance_category', 'detailed') 
#         as plaid_category_detailed,
#     m.name as merchant_name,
#     case when td.payee!='None' and td.payee is not null then td.payee
#         when td.payer!='None' and td.payer is not null then td.payer
#         else Null end as transfer_counterparty_name,

#     coalesce(tt.corrected_made_on, tt.made_on) as transaction_date,

#     case when tt.amount < 0 then 'Out'
#          when tt.amount > 0 then 'In'
#          else 'Zero'
#         end as direction, 
#     abs(tt.amount) as amount, 
#     tt.currency_code,
    
        
#     tt.description as description_1,
#     json_extract_path_text(tt.login_provider_additional_attributes, 'original_description') 
#         as description_2,
#     json_extract_path_text(tt.login_provider_additional_attributes, 'merchant_name') 
#         as additional_merchant_name,
#     td.company as original_transfer_counterparty_name,
    
#     td.payee,
#     td.payer,
    
#     json_extract_path_text(tt.login_provider_additional_attributes, 'payment_channel') 
#         as payment_channel,
#     json_extract_path_text(tt.login_provider_additional_attributes, 'location') 
#         as location,
#     tt.status

# from  presect_transactions tt
# left join transaction_categories tc on tc.id = tt.transaction_category_id
# left join transaction_descriptions td on td.transaction_id = tt.id
# left join merchants m on m.id = td.merchant_id and td.merchant_id is not null
# """)

# %%
sql_trans_with_merchant = """ 
with tt as (select
        tt.id,
        tt.amount,
        tt.corrected_made_on,
        tt.description,
        json_extract_path_text(tt.login_provider_additional_attributes, 'original_description')
        as original_description_plaid,
        json_extract_path_text(tt.login_provider_additional_attributes, 'merchant_name')
        as merchant_name_plaid,
        json_extract_path_text(tt.login_provider_additional_attributes, 'personal_finance_category', 'detailed')
        as category_detailed_plaid,
        json_extract_path_text(tt.login_provider_additional_attributes, 'personal_finance_category', 'primary')
        as category_primary_plaid,
        tt.made_on,
        tt.currency_code,

        json_extract_path_text(tt.login_provider_additional_attributes, 'payment_channel')
        as payment_channel,
        json_extract_path_text(tt.login_provider_additional_attributes, 'payment_method')
        as payment_method,
        json_extract_path_text(tt.login_provider_additional_attributes, 'payment_processor_method')
        as payment_processor_method,
        json_extract_path_text(tt.login_provider_additional_attributes, 'location','city')
        as city,
        json_extract_path_text(tt.login_provider_additional_attributes, 'location','region')
        as region,
        json_extract_path_text(tt.login_provider_additional_attributes, 'location','country')
        as country,
        tt.transaction_category_id,
        tt.login_provider_additional_attributes,
        tt.status
    from transactions tt
    where tt.made_on between '2024-03-02' and '2024-03-03'
    limit 100 )

select  tt.id,
        tt.amount,
        coalesce(tt.corrected_made_on, tt.made_on) as transaction_date,
        tt.corrected_made_on,
        tt.description,
        json_extract_path_text(tt.login_provider_additional_attributes, 'original_description')
        as original_description_plaid,
        json_extract_path_text(tt.login_provider_additional_attributes, 'merchant_name')
        as merchant_name_plaid,
        mm.name as merchant_name,
        mm.website as merchant_website,
        mm.twitter_name,
        mm.latitude as merchant_latitude,
        mm.longitude as merchant_longitude,

        json_extract_path_text(tt.login_provider_additional_attributes, 'personal_finance_category', 'detailed')
        as category_detailed_plaid,
        json_extract_path_text(tt.login_provider_additional_attributes, 'personal_finance_category', 'primary')
        as category_primary_plaid,
        tt.made_on,
        tt.currency_code,

        json_extract_path_text(tt.login_provider_additional_attributes, 'payment_channel')
        as payment_channel,
        json_extract_path_text(tt.login_provider_additional_attributes, 'payment_method')
        as payment_method,
        json_extract_path_text(tt.login_provider_additional_attributes, 'payment_processor_method')
        as payment_processor_method,
        json_extract_path_text(tt.login_provider_additional_attributes, 'location','city')
        as city,
        json_extract_path_text(tt.login_provider_additional_attributes, 'location','region')
        as region,
        json_extract_path_text(tt.login_provider_additional_attributes, 'location','country')
        as country,
        tt.transaction_category_id,
        tt.login_provider_additional_attributes,
        tt.status,
        transaction_descriptions.merchant_id,
        case when transaction_descriptions.payee!='None' and transaction_descriptions.payee is not null then transaction_descriptions.payee
            when transaction_descriptions.payer!='None' and transaction_descriptions.payer is not null then transaction_descriptions.payer
            else Null end as transfer_counterparty_name
from tt
left join  transaction_descriptions on tt.id = transaction_descriptions.transaction_id
left join merchants mm on mm.id = transaction_descriptions.merchant_id

"""

# %%
start_date = '2024-05-20'
end_date = '2024-05-21'
sql_fct_trans_with_merchant = f"""  
select ftt.transaction_id,
       ftt.corrected_made_on,
       ftt.amount,
       ftt.currency_code,
       ftt.description,
    json_extract_path_text(ftt.login_provider_additional_attributes, 'original_description')
        as original_description_plaid,
       ftt.merchant_name,
       json_extract_path_text(ftt.login_provider_additional_attributes, 'merchant_name') as merchant_name_plaid,
    json_extract_path_text(ftt.login_provider_additional_attributes, 'transaction_type')
        as transaction_type_plaid,
      json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'name') AS counterparty_name,
    json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'type') AS counterparty_type,
    json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'website') AS counterparty_website,
    json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'logo_url') AS counterparty_logo_url,
    json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'entity_id') AS counterparty_entity_id,
    json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'confidence_level') AS counterparty_confidence_level,
       ftt.merchant_id,
       ftt.company,
        json_extract_path_text(ftt.login_provider_additional_attributes, 'personal_finance_category', 'detailed')
        as category_detailed_plaid,
        json_extract_path_text(ftt.login_provider_additional_attributes, 'personal_finance_category', 'primary')
        as category_primary_plaid,
        json_extract_path_text(ftt.login_provider_additional_attributes, 'payment_channel')
        as payment_channel,
        json_extract_path_text(ftt.login_provider_additional_attributes, 'payment_method')
        as payment_method,
        json_extract_path_text(ftt.login_provider_additional_attributes, 'payment_processor_method')
        as payment_processor_method,
        json_extract_path_text(ftt.login_provider_additional_attributes, 'location','city')
        as city,
        json_extract_path_text(ftt.login_provider_additional_attributes, 'location','region')
        as region,
        json_extract_path_text(ftt.login_provider_additional_attributes, 'location','country')
        as country,
        ftt.status,
       ftt.decline_code,
      ftt.login_provider_additional_attributes
from analytics.fct_transactions ftt
where corrected_made_on >= '{start_date}' and corrected_made_on <= '{end_date}'
and original_description_plaid is not null
and original_description_plaid != ''
and amount != 0.0
"""

# %%
print(sql_fct_trans_with_merchant)
# Out:
#
# select ftt.transaction_id,
#        ftt.corrected_made_on,
#        ftt.amount,
#        ftt.currency_code,
#        ftt.description,
#     json_extract_path_text(ftt.login_provider_additional_attributes, 'original_description')
#         as original_description_plaid,
#        ftt.merchant_name,
#        json_extract_path_text(ftt.login_provider_additional_attributes, 'merchant_name') as merchant_name_plaid,
#     json_extract_path_text(ftt.login_provider_additional_attributes, 'transaction_type')
#         as transaction_type_plaid,
#       json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'name') AS counterparty_name,
#     json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'type') AS counterparty_type,
#     json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'website') AS counterparty_website,
#     json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'logo_url') AS counterparty_logo_url,
#     json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'entity_id') AS counterparty_entity_id,
#     json_extract_path_text(ftt.login_provider_additional_attributes, 'counterparties', '0', 'confidence_level') AS counterparty_confidence_level,
#        ftt.merchant_id,
#        ftt.company,
#         json_extract_path_text(ftt.login_provider_additional_attributes, 'personal_finance_category', 'detailed')
#         as category_detailed_plaid,
#         json_extract_path_text(ftt.login_provider_additional_attributes, 'personal_finance_category', 'primary')
#         as category_primary_plaid,
#         json_extract_path_text(ftt.login_provider_additional_attributes, 'payment_channel')
#         as payment_channel,
#         json_extract_path_text(ftt.login_provider_additional_attributes, 'payment_method')
#         as payment_method,
#         json_extract_path_text(ftt.login_provider_additional_attributes, 'payment_processor_method')
#         as payment_processor_method,
#         json_extract_path_text(ftt.login_provider_additional_attributes, 'location','city')
#         as city,
#         json_extract_path_text(ftt.login_provider_additional_attributes, 'location','region')
#         as region,
#         json_extract_path_text(ftt.login_provider_additional_attributes, 'location','country')
#         as country,
#         ftt.status,
#        ftt.decline_code,
#       ftt.login_provider_additional_attributes
# from analytics.fct_transactions ftt
# where corrected_made_on >= '2024-05-10' and corrected_made_on <= '2024-05-21'
# and original_description_plaid is not null
# and original_description_plaid != ''
# and amount != 0.0

# %%
run_one_off = 1
if run_one_off==0 :
    df_trans_orig = redshift_source.fetch_data(sql_fct_trans_with_merchant)
elif run_one_off == 1:
    dataset_id = datetime.now().strftime("%y%m%d_%H%M")

    sql = f"""
    unload ('select * from ({sql_fct_trans_with_merchant.replace("'", "''")}
    )')
        to 's3://cleo-data-science/transaction_enrichment/experimental_data/caste/raw/trans_{start_date}_{end_date}_{dataset_id}'
        iam_role 'arn:aws:iam::878877078763:role/CleoRedshiftToS3'
        format as parquet
        cleanpath;"""
    print(sql)
    redshift_source.execute_query(sql)
    
    path_file = f"s3://cleo-data-science/transaction_enrichment/experimental_data/caste/raw/trans_{start_date}_{end_date}_{dataset_id}"
    print(path_file)
    df_trans = read_from_s3(path_file)
    # bucket_name = path_file.split('://')[1].split('/')[0]
    # key = path_file.split('://')[1].split(bucket_name)[1][1:]
    # print(f"bucket {bucket_name}")
    # print(f"key {key}")
    # df_trans  = read_csv_s3(bucket_name, key )
elif run_one_off ==2:
    path_file = "s3://cleo-data-science/transaction_enrichment/experimental_data/caste/raw/trans_2024-05-20_2024-05-20"
    df_trans = read_from_s3(path_file)
# Out:
#     unload ('select * from (
# select ftt.transaction_id,
#        ftt.corrected_made_on,
#        ftt.amount,
#        ftt.currency_code,
#        ftt.description,
#     json_extract_path_text(ftt.login_provider_additional_attributes, ''original_description'')
#         as original_description_plaid,
#        ftt.merchant_name,
#        json_extract_path_text(ftt.login_provider_additional_attributes, ''merchant_name'') as merchant_name_plaid,
#     json_extract_path_text(ftt.login_provider_additional_attributes, ''transaction_type'')
#         as transaction_type_plaid,
#       json_extract_path_text(ftt.login_provider_additional_attributes, ''counterparties'', ''0'', ''name'') AS counterparty_name,
#     json_extract_path_text(ftt.login_provider_additional_attributes, ''counterparties'', ''0'', ''type'') AS counterparty_type,
#     json_extract_path_text(ftt.login_provider_additional_attributes, ''counterparties'', ''0'', ''website'') AS counterparty_website,
#     json_extract_path_text(ftt.login_provider_additional_attributes, ''counterparties'', ''0'', ''logo_url'') AS counterparty_logo_url,
#     json_extract_path_text(ftt.login_provider_additional_attributes, ''counterparties'', ''0'', ''entity_id'') AS counterparty_entity_id,
#     json_extract_path_text(ftt.login_provider_additional_attributes, ''counterparties'', ''0'', ''confidence_level'') AS counterparty_confidence_level,
#        ftt.merchant_id,
#        ftt.company,
#         json_extract_path_text(ftt.login_provider_additional_attributes, ''personal_finance_category'', ''detailed'')
#         as category_detailed_plaid,
#         json_extract_path_text(ftt.login_provider_additional_attributes, ''personal_finance_category'', ''primary'')
#         as category_primary_plaid,
#         json_extract_path_text(ftt.login_provider_additional_attributes, ''payment_channel'')
#         as payment_channel,
#         json_extract_path_text(ftt.login_provider_additional_attributes, ''payment_method'')
#         as payment_method,
#         json_extract_path_text(ftt.login_provider_additional_attributes, ''payment_processor_method'')
#         as payment_processor_method,
#         json_extract_path_text(ftt.login_provider_additional_attributes, ''location'',''city'')
#         as city,
#         json_extract_path_text(ftt.login_provider_additional_attributes, ''location'',''region'')
#         as region,
#         json_extract_path_text(ftt.login_provider_additional_attributes, ''location'',''country'')
#         as country,
#         ftt.status,
#        ftt.decline_code,
#       ftt.login_provider_additional_attributes
# from analytics.fct_transactions ftt
# where corrected_made_on >= ''2024-05-10'' and corrected_made_on <= ''2024-05-21''
# and original_description_plaid is not null
# and original_description_plaid != ''''
# and amount != 0.0
#
#     )')
#         to 's3://cleo-data-science/transaction_enrichment/experimental_data/caste/raw/trans_2024-05-10_2024-05-21_240522_1457'
#         iam_role 'arn:aws:iam::878877078763:role/CleoRedshiftToS3'
#         format as parquet
#         cleanpath;

# %%
path_file_processed = path_file.split('raw/')[0]+'processed/'+path_file.split('raw/')[1]
path_file_processed
# Out:
# 's3://cleo-data-science/transaction_enrichment/experimental_data/caste/processed/trans_2024-05-20_2024-05-20'

# %%
df_trans
# Out:
#          transaction_id corrected_made_on  amount currency_code  \
# 0            9848927082        2024-05-20  -24.60           USD
# 1            9848923081        2024-05-20   25.00           USD
# 2            9848926033        2024-05-20 -336.00           USD
# 3            9848926035        2024-05-20   -7.86           USD
# 4            9848926034        2024-05-20   -7.86           USD
# ...                 ...               ...     ...           ...
# 6492889      9857334046        2024-05-20  -15.00           USD
# 6492890      9857334047        2024-05-20  -25.00           USD
# 6492891      9857334048        2024-05-20  -25.00           USD
# 6492892      9857334049        2024-05-20  -25.00           USD
# 6492893      9857334050        2024-05-20  -25.00           USD
#
#                                    description  \
# 0                       GOOGLE *YouTubePremium
# 1        ZELLE P2P PAYMENT RECEIVED ON 05/19 \
# 2                   CashAdvance / Cash Advance
# 3                                  McDonald''s
# 4                                  McDonald''s
# ...                                        ...
# 6492889                                FanDuel
# 6492890                                FanDuel
# 6492891                                FanDuel
# 6492892                                FanDuel
# 6492893                                FanDuel
#
#                                 original_description_plaid    merchant_name  \
# 0                                                           YouTube Premium
# 1                ZELLE P2P PAYMENT RECEIVED ON 05/19    \\             None
# 2                               CashAdvance / Cash Advance             None
# 3        Purchase / McDonalds 35052 142-3328095, TN (4633)      McDonald''s
# 4        Purchase / McDonalds 35052 142-3328095, TN (4633)      McDonald''s
# ...                                                    ...              ...
# 6492889                                            FanDuel          FanDuel
# 6492890                                            FanDuel          FanDuel
# 6492891                                            FanDuel          FanDuel
# 6492892                                            FanDuel          FanDuel
# 6492893                                            FanDuel          FanDuel
#
#         merchant_name_plaid transaction_type_plaid counterparty_name  ...  \
# 0                                                                     ...
# 1                                          special             Zelle  ...
# 2                                            place                    ...
# 3               McDonald''s                  place       McDonald''s  ...
# 4               McDonald''s                  place       McDonald''s  ...
# ...                     ...                    ...               ...  ...
# 6492889             FanDuel                  place           FanDuel  ...
# 6492890             FanDuel                  place           FanDuel  ...
# 6492891             FanDuel                  place           FanDuel  ...
# 6492892             FanDuel                  place           FanDuel  ...
# 6492893             FanDuel                  place           FanDuel  ...
#
#         category_primary_plaid payment_channel payment_method  \
# 0
# 1                  TRANSFER_IN           other
# 2                LOAN_PAYMENTS           other
# 3               FOOD_AND_DRINK        in store
# 4               FOOD_AND_DRINK        in store
# ...                        ...             ...            ...
# 6492889          ENTERTAINMENT        in store
# 6492890          ENTERTAINMENT        in store
# 6492891          ENTERTAINMENT        in store
# 6492892          ENTERTAINMENT        in store
# 6492893          ENTERTAINMENT        in store
#
#         payment_processor_method city  region country    status  \
# 0                                                      declined
# 1                                                          None
# 2                                                          None
# 3                                                          None
# 4                                                          None
# ...                          ...  ...     ...     ...       ...
# 6492889                                                    None
# 6492890                                                    None
# 6492891                                                    None
# 6492892                                                    None
# 6492893                                                    None
#
#                  decline_code  \
# 0        not sufficient funds
# 1
# 2
# 3
# 4
# ...                       ...
# 6492889
# 6492890
# 6492891
# 6492892
# 6492893
#
#                       login_provider_additional_attributes
# 0                                           {"type": "00"}
# 1        {"datetime": null, "location": {"lat": null, "...
# 2        {"datetime": null, "location": {"lat": null, "...
# 3        {"datetime": null, "location": {"lat": null, "...
# 4        {"datetime": null, "location": {"lat": null, "...
# ...                                                    ...
# 6492889  {"datetime": "2024-05-20T20:09:51.000Z", "loca...
# 6492890  {"datetime": "2024-05-20T20:09:52.000Z", "loca...
# 6492891  {"datetime": "2024-05-20T20:09:51.000Z", "loca...
# 6492892  {"datetime": "2024-05-20T20:09:51.000Z", "loca...
# 6492893  {"datetime": "2024-05-20T20:09:51.000Z", "loca...
#
# [6492894 rows x 28 columns]

# %% [markdown]
# If merchant name is not present, user merchant_name_plaid.
# If merchant_name is not present, use counterparty_name

# %%
#replace None with null
df_trans['merchant_name'] = df_trans['merchant_name'].map({'None':None})
df_trans['merchant_name_plaid'] = df_trans['merchant_name_plaid'].map({'':None,' ':None})
# create a column combined_merchant where we take the any merchant name : Cleo, or plaid, or counterparty 
df_trans['merchant_name_combined'] = df_trans['merchant_name'].combine_first(df_trans['merchant_name_plaid'])
df_trans['merchant_name_combined'] = df_trans['merchant_name_combined'].combine_first(df_trans['counterparty_name'])
# Remove data without merchant name for training data
df_trans_cln = df_trans[(~df_trans['merchant_name_combined'].isnull()) & ~df_trans['merchant_name_combined'].isin(['',' '])]

# %%
df_trans_no_merchant = df_trans[(df_trans['merchant_name_combined'].isnull()) | df_trans['merchant_name_combined'].isin(['',' '])]

# %%
df_trans_no_merchant
# Out:
#          transaction_id corrected_made_on  amount currency_code  \
# 0            9848927082        2024-05-20  -24.60           USD
# 2            9848926033        2024-05-20 -336.00           USD
# 5            9848932218        2024-05-20   75.00           USD
# 6            9848944528        2024-05-20   25.00           USD
# 7            9848944529        2024-05-20  -25.00           USD
# ...                 ...               ...     ...           ...
# 6492841      9869982569        2024-05-20 -100.00           USD
# 6492842      9869982568        2024-05-20  100.00           USD
# 6492855      9869982906        2024-05-20  324.11           USD
# 6492861      9869983481        2024-05-20   17.33           USD
# 6492862      9869983480        2024-05-20  -20.00           USD
#
#                                            description  \
# 0                               GOOGLE *YouTubePremium
# 2                           CashAdvance / Cash Advance
# 5                                               CREDIT
# 6           Mobile Banking Transfer Deposit 05/18 0056
# 7        Mobile Banking Transfer Withdrawal 05/18 0901
# ...                                                ...
# 6492841                          ONLINE TRANSFER DEBIT
# 6492842                         ONLINE TRANSFER CREDIT
# 6492855         TENDER CARE VETERINARY FALCON CO 05/19
# 6492861                Pos Adjustment - Cr Tiktok Shop
# 6492862                       Overdraft Protection Fee
#
#                               original_description_plaid merchant_name  \
# 0                                                                  NaN
# 2                             CashAdvance / Cash Advance           NaN
# 5                                                 CREDIT           NaN
# 6             Mobile Banking Transfer Deposit 05/18 0056           NaN
# 7          Mobile Banking Transfer Withdrawal 05/18 0901           NaN
# ...                                                  ...           ...
# 6492841                            ONLINE TRANSFER DEBIT           NaN
# 6492842                           ONLINE TRANSFER CREDIT           NaN
# 6492855           TENDER CARE VETERINARY FALCON CO 05/19           NaN
# 6492861  Pos Adjustment - Cr Tiktok Shop 650-584-0896 CA           NaN
# 6492862                         Overdraft Protection Fee           NaN
#
#         merchant_name_plaid transaction_type_plaid counterparty_name  ...  \
# 0                      None                                           ...
# 2                      None                  place                    ...
# 5                      None                special                    ...
# 6                      None                special                    ...
# 7                      None                special                    ...
# ...                     ...                    ...               ...  ...
# 6492841                None                special                    ...
# 6492842                None                special                    ...
# 6492855                None                  place                    ...
# 6492861                None                special                    ...
# 6492862                None                special                    ...
#
#         payment_channel payment_method payment_processor_method    city  \
# 0
# 2                 other
# 5                 other
# 6                 other
# 7                 other
# ...                 ...            ...                      ...     ...
# 6492841           other
# 6492842           other
# 6492855           other                                          Falcon
# 6492861           other
# 6492862           other
#
#         region  country    status          decline_code  \
# 0                        declined  not sufficient funds
# 2                            None
# 5                            None
# 6                            None
# 7                            None
# ...        ...      ...       ...                   ...
# 6492841                      None
# 6492842                      None
# 6492855     CO               None
# 6492861     CA               None
# 6492862                      None
#
#                       login_provider_additional_attributes  \
# 0                                           {"type": "00"}
# 2        {"datetime": null, "location": {"lat": null, "...
# 5        {"datetime": null, "location": {"lat": null, "...
# 6        {"datetime": "2024-05-20T00:00:00.000Z", "loca...
# 7        {"datetime": "2024-05-20T00:00:00.000Z", "loca...
# ...                                                    ...
# 6492841  {"datetime": null, "location": {"lat": null, "...
# 6492842  {"datetime": null, "location": {"lat": null, "...
# 6492855  {"datetime": null, "location": {"lat": null, "...
# 6492861  {"datetime": null, "location": {"lat": null, "...
# 6492862  {"datetime": null, "location": {"lat": null, "...
#
#         merchant_name_combined
# 0
# 2
# 5
# 6
# 7
# ...                        ...
# 6492841
# 6492842
# 6492855
# 6492861
# 6492862
#
# [1156063 rows x 29 columns]

# %%
print(df_trans.shape)
print(df_trans_cln.shape)
# Out:
# (6492894, 29)
# (5336831, 29)

# %%
df_trans_cln['merchant_name_combined'].value_counts()
# Out:
# merchant_name_combined
# Cash App                   346486
# Zelle                      172242
# Walmart                    115901
# Apple                      114375
# Earnin                     108338
#                             ...
# Old River Donuts                1
# Burnside                        1
# Mjp Management                  1
# Spotifyusai Angel Lopez         1
# Anju House                      1
# Name: count, Length: 426343, dtype: int64

# %%
nunique_merchants = df_trans_cln['merchant_name_combined'].nunique()
print(f"There are {nunique_merchants}  in the dataset")
# Out:
# There are 426343  in the dataset

# %%
# There are some cases where Chime is the merchant but it isn't mentioned in the description, so remove these
df_trans_cln.reset_index(inplace=True, drop=True)
df_trans_cln['Chime in descr'] = df_trans_cln['original_description_plaid'].apply(lambda x: 'Chime' in x)
df_trans_cln2 = df_trans_cln[(df_trans_cln['Chime in descr'] & (df_trans_cln['merchant_name_combined']=='Chime')) | (df_trans_cln['merchant_name_combined']!='Chime')]
df_trans_cln2.reset_index(drop=True, inplace=True)
df_trans_cln2
# Out:
# /var/folders/96/34ycxb693ss1n858z5ck1xwh0000gn/T/ipykernel_25025/3417653004.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trans_cln['Chime in descr'] = df_trans_cln['original_description_plaid'].apply(lambda x: 'Chime' in x)
#          transaction_id corrected_made_on  amount currency_code  \
# 0            9848923081        2024-05-20   25.00           USD
# 1            9848926035        2024-05-20   -7.86           USD
# 2            9848926034        2024-05-20   -7.86           USD
# 3            9848945525        2024-05-20   19.65           USD
# 4            9848948208        2024-05-20 -100.00           USD
# ...                 ...               ...     ...           ...
# 5291196      9857334046        2024-05-20  -15.00           USD
# 5291197      9857334047        2024-05-20  -25.00           USD
# 5291198      9857334048        2024-05-20  -25.00           USD
# 5291199      9857334049        2024-05-20  -25.00           USD
# 5291200      9857334050        2024-05-20  -25.00           USD
#
#                                                description  \
# 0                    ZELLE P2P PAYMENT RECEIVED ON 05/19 \
# 1                                              McDonald''s
# 2                                              McDonald''s
# 3                                   Transfer from Cash App
# 4        POS Withdrawal (FIS) Q NAILS Q NAILS NEWPORT T...
# ...                                                    ...
# 5291196                                            FanDuel
# 5291197                                            FanDuel
# 5291198                                            FanDuel
# 5291199                                            FanDuel
# 5291200                                            FanDuel
#
#                                 original_description_plaid merchant_name  \
# 0                ZELLE P2P PAYMENT RECEIVED ON 05/19    \\           NaN
# 1        Purchase / McDonalds 35052 142-3328095, TN (4633)           NaN
# 2        Purchase / McDonalds 35052 142-3328095, TN (4633)           NaN
# 3                                   Transfer from Cash App           NaN
# 4        POS Withdrawal (FIS) Q NAILS Q NAILS NEWPORT T...           NaN
# ...                                                    ...           ...
# 5291196                                            FanDuel           NaN
# 5291197                                            FanDuel           NaN
# 5291198                                            FanDuel           NaN
# 5291199                                            FanDuel           NaN
# 5291200                                            FanDuel           NaN
#
#         merchant_name_plaid transaction_type_plaid counterparty_name  ...  \
# 0                      None                special             Zelle  ...
# 1                       NaN                  place       McDonald''s  ...
# 2                       NaN                  place       McDonald''s  ...
# 3                      None                special          Cash App  ...
# 4                       NaN                  place           Q Nails  ...
# ...                     ...                    ...               ...  ...
# 5291196                 NaN                  place           FanDuel  ...
# 5291197                 NaN                  place           FanDuel  ...
# 5291198                 NaN                  place           FanDuel  ...
# 5291199                 NaN                  place           FanDuel  ...
# 5291200                 NaN                  place           FanDuel  ...
#
#         payment_method payment_processor_method     city region country  \
# 0
# 1
# 2
# 3
# 4                                                Newport     TN
# ...                ...                      ...      ...    ...     ...
# 5291196
# 5291197
# 5291198
# 5291199
# 5291200
#
#          status decline_code  \
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...          ...
# 5291196    None
# 5291197    None
# 5291198    None
# 5291199    None
# 5291200    None
#
#                       login_provider_additional_attributes  \
# 0        {"datetime": null, "location": {"lat": null, "...
# 1        {"datetime": null, "location": {"lat": null, "...
# 2        {"datetime": null, "location": {"lat": null, "...
# 3        {"datetime": null, "location": {"lat": null, "...
# 4        {"datetime": null, "location": {"lat": null, "...
# ...                                                    ...
# 5291196  {"datetime": "2024-05-20T20:09:51.000Z", "loca...
# 5291197  {"datetime": "2024-05-20T20:09:52.000Z", "loca...
# 5291198  {"datetime": "2024-05-20T20:09:51.000Z", "loca...
# 5291199  {"datetime": "2024-05-20T20:09:51.000Z", "loca...
# 5291200  {"datetime": "2024-05-20T20:09:51.000Z", "loca...
#
#         merchant_name_combined Chime in descr
# 0                        Zelle          False
# 1                  McDonald''s          False
# 2                  McDonald''s          False
# 3                     Cash App          False
# 4                      Q Nails          False
# ...                        ...            ...
# 5291196                FanDuel          False
# 5291197                FanDuel          False
# 5291198                FanDuel          False
# 5291199                FanDuel          False
# 5291200                FanDuel          False
#
# [5291201 rows x 30 columns]

# %%
df_counts = df_trans_cln2['merchant_name_combined'].value_counts()
df_counts
df_counts[0:30]
# Out:
# merchant_name_combined
# Cash App              346486
# Zelle                 172242
# Walmart               115901
# Apple                 114375
# Earnin                108338
# McDonald''s            96105
# Cleo                   94816
# Amazon                 90189
# Apple Cash             82400
# MoneyLion              68428
# Uber                   63681
# Varo                   61104
# Dave                   60827
# Brigit                 57196
# Chime                  56630
# Venmo                  56618
# Empower                53624
# Wells Fargo            47905
# Albert                 47596
# Shell                  44768
# AfterPay               44643
# PayPal                 44308
# 7-Eleven               43490
# Dollar General         42236
# FanDuel Sportsbook     41727
# Circle K               41000
# USAA                   40737
# Uber Eats              38169
# Klover App             37711
# Starbucks              34059
# Name: count, dtype: int64

# %%
nunique_merchants = df_trans_cln['merchant_name_combined'].nunique()
print(f"There are {nunique_merchants}  in the dataset")
# Out:
# There are 426343  in the dataset

# %%
df_trans_cln2[df_trans_cln2['merchant_name_combined']=="Uber Eats"]
# Out:
#          transaction_id corrected_made_on  amount currency_code description  \
# 248          9849310484        2024-05-20  -11.53           USD   Uber Eats
# 270          9849334721        2024-05-20  -21.50           USD   Uber Eats
# 491          9849685081        2024-05-20  -22.72           USD   Uber Eats
# 760          9849846630        2024-05-20  -16.98           USD   Uber Eats
# 761          9849846631        2024-05-20  -45.10           USD   Uber Eats
# ...                 ...               ...     ...           ...         ...
# 5291100      9869969452        2024-05-20  -41.30           USD   Uber Eats
# 5291110      9869969450        2024-05-20   34.62           USD   Uber Eats
# 5291150      9869976693        2024-05-20   -7.92           USD   Uber Eats
# 5291151      9869976695        2024-05-20  -33.56           USD   Uber Eats
# 5291177      9869983896        2024-05-20  -26.35           USD   Uber Eats
#
#                                 original_description_plaid merchant_name  \
# 248      DB DEBIT - 5-19-2024, UBER   EATS             ...           NaN
# 270      WITHDRAWAL. POS 0519 1945 819414 UBER   *EATS ...           NaN
# 491      DEBIT CARD DEBIT / ref #000872020321 05-18-202...           NaN
# 760                                              Uber Eats           NaN
# 761                                              Uber Eats           NaN
# ...                                                    ...           ...
# 5291100           UBER *EATS SAN FRANCISCO CA 816488 05/19           NaN
# 5291110           UBER *EATS SAN FRANCISCO CA 230274 05/19           NaN
# 5291150           UBER *EATS SAN FRANCISCO CA 585375 05/20           NaN
# 5291151           UBER *EATS SAN FRANCISCO CA 054331 05/20           NaN
# 5291177                   UBER EATS HELP.UBER.COM CA 05/19           NaN
#
#         merchant_name_plaid transaction_type_plaid counterparty_name  ...  \
# 248                     NaN                  place         Uber Eats  ...
# 270                     NaN                  place         Uber Eats  ...
# 491                     NaN                  place         Uber Eats  ...
# 760                     NaN                  place         Uber Eats  ...
# 761                     NaN                  place         Uber Eats  ...
# ...                     ...                    ...               ...  ...
# 5291100                 NaN                  place         Uber Eats  ...
# 5291110                 NaN                  place         Uber Eats  ...
# 5291150                 NaN                  place         Uber Eats  ...
# 5291151                 NaN                  place         Uber Eats  ...
# 5291177                 NaN                  place         Uber Eats  ...
#
#         payment_method payment_processor_method           city region country  \
# 248
# 270                                              San Francisco     CA
# 491
# 760
# 761
# ...                ...                      ...            ...    ...     ...
# 5291100
# 5291110                                          San Francisco     CA
# 5291150
# 5291151
# 5291177
#
#          status decline_code  \
# 248        None
# 270        None
# 491        None
# 760        None
# 761        None
# ...         ...          ...
# 5291100    None
# 5291110    None
# 5291150    None
# 5291151    None
# 5291177    None
#
#                       login_provider_additional_attributes  \
# 248      {"datetime": null, "location": {"lat": null, "...
# 270      {"datetime": null, "location": {"lat": null, "...
# 491      {"datetime": null, "location": {"lat": null, "...
# 760      {"datetime": null, "location": {"lat": null, "...
# 761      {"datetime": null, "location": {"lat": null, "...
# ...                                                    ...
# 5291100  {"datetime": null, "location": {"lat": null, "...
# 5291110  {"datetime": null, "location": {"lat": null, "...
# 5291150  {"datetime": null, "location": {"lat": null, "...
# 5291151  {"datetime": null, "location": {"lat": null, "...
# 5291177  {"datetime": null, "location": {"lat": null, "...
#
#         merchant_name_combined Chime in descr
# 248                  Uber Eats          False
# 270                  Uber Eats          False
# 491                  Uber Eats          False
# 760                  Uber Eats          False
# 761                  Uber Eats          False
# ...                        ...            ...
# 5291100              Uber Eats          False
# 5291110              Uber Eats          False
# 5291150              Uber Eats          False
# 5291151              Uber Eats          False
# 5291177              Uber Eats          False
#
# [38169 rows x 30 columns]

# %%
# examples where the description and the merchant name are the same are probably not too informative
df_trans_cln3 = df_trans_cln2[df_trans_cln2['merchant_name_combined']!=df_trans_cln2['original_description_plaid']]
print(df_trans_cln3.shape)
df_trans_cln3['merchant_name_combined'].value_counts()[:-40]
# Out:
# (4930071, 30)
# merchant_name_combined
# Cash App                     341036
# Zelle                        172238
# Earnin                       107179
# Apple                        103460
# Walmart                       97783
#                               ...
# Element By Marriot                1
# Bottle House-dc                   1
# The Barac Co                      1
# Antaniah White                    1
# Animal Dermatology Clinic         1
# Name: count, Length: 385024, dtype: int64

# %%
def look_up_for_one_merchant(merchant_name, df):
    return df[df['merchant_name_combined']==merchant_name]

# %%
look_up_for_one_merchant('Affirm', df_trans_cln3)
# Out:
#          transaction_id corrected_made_on  amount currency_code  \
# 958          9849972534        2024-05-20   18.07           USD
# 2092         9850419943        2024-05-20   -7.13           USD
# 2093         9850419944        2024-05-20  -12.72           USD
# 2094         9850419945        2024-05-20  -13.95           USD
# 2095         9850419946        2024-05-20  -13.95           USD
# ...                 ...               ...     ...           ...
# 5288047      9869632565        2024-05-20 -512.10           USD
# 5289254      9869748085        2024-05-20  -15.33           USD
# 5290784      9869937536        2024-05-20   -7.51           USD
# 5290795      9869937538        2024-05-20  -12.96           USD
# 5290796      9869937520        2024-05-20  -11.03           USD
#
#                                               description  \
# 958                                       AFFIRM *PAYMENT
# 2092                                AFFIRM INC AFFIRM PAY
# 2093                                AFFIRM INC AFFIRM PAY
# 2094                                AFFIRM INC AFFIRM PAY
# 2095                                AFFIRM INC AFFIRM PAY
# ...                                                   ...
# 5288047         ACH Debit - Affirm Inc Affirm Pay 2100002
# 5289254  AFFIRM INC AFFIRM PAY 9381277 WEB ID: 0000317218
# 5290784                    AFFIRM * PAY N628ZC3O CA 05/19
# 5290795                    AFFIRM * PAY OVXOUFVC CA 05/19
# 5290796                    AFFIRM * PAY IJW9QYC7 CA 05/19
#
#                                original_description_plaid merchant_name  \
# 958                       AFFIRM *PAYMENT 855-423-3729 CA           NaN
# 2092                                AFFIRM INC AFFIRM PAY           NaN
# 2093                                AFFIRM INC AFFIRM PAY           NaN
# 2094                                AFFIRM INC AFFIRM PAY           NaN
# 2095                                AFFIRM INC AFFIRM PAY           NaN
# ...                                                   ...           ...
# 5288047        ACH Debit - Affirm Inc  Affirm Pay 2100002           NaN
# 5289254  AFFIRM INC AFFIRM PAY 9381277 WEB ID: 0000317218           NaN
# 5290784       AFFIRM * PAY N628ZC3O 855-423-3729 CA 05/19           NaN
# 5290795       AFFIRM * PAY OVXOUFVC 855-423-3729 CA 05/19           NaN
# 5290796       AFFIRM * PAY IJW9QYC7 855-423-3729 CA 05/19           NaN
#
#         merchant_name_plaid transaction_type_plaid counterparty_name  ...  \
# 958                     NaN                  place            Affirm  ...
# 2092                    NaN                  place            Affirm  ...
# 2093                    NaN                  place            Affirm  ...
# 2094                    NaN                  place            Affirm  ...
# 2095                    NaN                  place            Affirm  ...
# ...                     ...                    ...               ...  ...
# 5288047                 NaN                  place            Affirm  ...
# 5289254                 NaN                  place            Affirm  ...
# 5290784                 NaN                  place            Affirm  ...
# 5290795                 NaN                  place            Affirm  ...
# 5290796                 NaN                  place            Affirm  ...
#
#         payment_method payment_processor_method city region country  status  \
# 958                                                      CA            None
# 2092                                                                   None
# 2093                                                                   None
# 2094                                                                   None
# 2095                                                                   None
# ...                ...                      ...  ...    ...     ...     ...
# 5288047                                                                None
# 5289254                                                                None
# 5290784                                                                None
# 5290795                                                                None
# 5290796                                                                None
#
#         decline_code               login_provider_additional_attributes  \
# 958                   {"datetime": null, "location": {"lat": null, "...
# 2092                  {"datetime": null, "location": {"lat": null, "...
# 2093                  {"datetime": null, "location": {"lat": null, "...
# 2094                  {"datetime": null, "location": {"lat": null, "...
# 2095                  {"datetime": null, "location": {"lat": null, "...
# ...              ...                                                ...
# 5288047               {"datetime": null, "location": {"lat": null, "...
# 5289254               {"datetime": null, "location": {"lat": null, "...
# 5290784               {"datetime": null, "location": {"lat": null, "...
# 5290795               {"datetime": null, "location": {"lat": null, "...
# 5290796               {"datetime": null, "location": {"lat": null, "...
#
#         merchant_name_combined Chime in descr
# 958                     Affirm          False
# 2092                    Affirm          False
# 2093                    Affirm          False
# 2094                    Affirm          False
# 2095                    Affirm          False
# ...                        ...            ...
# 5288047                 Affirm          False
# 5289254                 Affirm          False
# 5290784                 Affirm          False
# 5290795                 Affirm          False
# 5290796                 Affirm          False
#
# [23614 rows x 30 columns]

# %%
df_trans_cln3.columns
# Out:
# Index(['transaction_id', 'corrected_made_on', 'amount', 'currency_code',
#        'description', 'original_description_plaid', 'merchant_name',
#        'merchant_name_plaid', 'transaction_type_plaid', 'counterparty_name',
#        'counterparty_type', 'counterparty_website', 'counterparty_logo_url',
#        'counterparty_entity_id', 'counterparty_confidence_level',
#        'merchant_id', 'company', 'category_detailed_plaid',
#        'category_primary_plaid', 'payment_channel', 'payment_method',
#        'payment_processor_method', 'city', 'region', 'country', 'status',
#        'decline_code', 'login_provider_additional_attributes',
#        'merchant_name_combined', 'Chime in descr'],
#       dtype='object')

# %%
columns_to_keep = ['transaction_id','corrected_made_on','amount','original_description_plaid','merchant_name_combined','payment_channel']

# %%
df_trans_cln3[columns_to_keep]
# Out:
#          transaction_id corrected_made_on  amount  \
# 0            9848923081        2024-05-20   25.00
# 1            9848926035        2024-05-20   -7.86
# 2            9848926034        2024-05-20   -7.86
# 3            9848945525        2024-05-20   19.65
# 4            9848948208        2024-05-20 -100.00
# ...                 ...               ...     ...
# 5291189      9869983888        2024-05-20   -2.17
# 5291190      9869983879        2024-05-20   -6.00
# 5291191      9869983880        2024-05-20 -115.47
# 5291192      9869983882        2024-05-20 -130.00
# 5291193      9869983894        2024-05-20  -20.98
#
#                                 original_description_plaid  \
# 0                ZELLE P2P PAYMENT RECEIVED ON 05/19    \\
# 1        Purchase / McDonalds 35052 142-3328095, TN (4633)
# 2        Purchase / McDonalds 35052 142-3328095, TN (4633)
# 3                                   Transfer from Cash App
# 4        POS Withdrawal (FIS) Q NAILS Q NAILS NEWPORT T...
# ...                                                    ...
# 5291189        PIZZARONI BELL GARDEN BELL GARDENS CA 05/19
# 5291190     ALBERT CASH 000000249530974 WEB ID: 1475215705
# 5291191                    ANJU HOUSE LOS ANGELES CA 05/17
# 5291192      SQ *FRANK ''N HANK''S BA Los Angeles CA 05/18
# 5291193           UBER *TRIP SAN FRANCISCO CA 006673 05/20
#
#          merchant_name_combined payment_channel
# 0                         Zelle           other
# 1                   McDonald''s        in store
# 2                   McDonald''s        in store
# 3                      Cash App           other
# 4                       Q Nails        in store
# ...                         ...             ...
# 5291189  Pizzaroni Bell Gardens        in store
# 5291190                  Albert           other
# 5291191              Anju House        in store
# 5291192           Frank N Hanks        in store
# 5291193                    Uber          online
#
# [4930071 rows x 6 columns]

# %%
# save this dataset and depending on the type of algorithm you can choose how to reorder the data

df_trans_cln3.to_parquet(path_file_processed)

# %%
print(f"Finsihed writing file {path_file_processed}")

# %%
#df_trans_cln3.to_csv('/Users/claracastellanos/Documents/DATA/MERCHANTS/2024_05_20.csv')

# %%
#load data back in to make sure everythin is ok
df_tmp = read_from_s3("s3://cleo-data-science/transaction_enrichment/experimental_data/caste/biencoder_test1/data1")

# %%
df_tmp.shape
# Out:
# (956812, 30)

# %%
df_tmp
# Out:
#          transaction_id corrected_made_on  amount currency_code  \
# index
# 0            9848923081        2024-05-20   25.00           USD
# 1            9848926035        2024-05-20   -7.86           USD
# 2            9848926034        2024-05-20   -7.86           USD
# 3            9848945525        2024-05-20   19.65           USD
# 4            9848948208        2024-05-20 -100.00           USD
# ...                 ...               ...     ...           ...
# 1170552      9857528533        2024-05-20  -63.27           USD
# 1170554      9857528559        2024-05-20  -34.70           USD
# 1170555      9857528629        2024-05-20  -10.28           USD
# 1170556      9857528627        2024-05-20   10.00           USD
# 1170557      9857528782        2024-05-20   -4.98           USD
#
#                                                description  \
# index
# 0                    ZELLE P2P PAYMENT RECEIVED ON 05/19 \
# 1                                              McDonald''s
# 2                                              McDonald''s
# 3                                   Transfer from Cash App
# 4        POS Withdrawal (FIS) Q NAILS Q NAILS NEWPORT T...
# ...                                                    ...
# 1170552                             Cash App*Anthony Cenic
# 1170554  Point Of Sale Withdrawal 445488848992 DD DOORD...
# 1170555                  Transfer to Chime Savings Account
# 1170556                Transfer from Chime Savings Account
# 1170557                                          Walgreens
#
#                                 original_description_plaid merchant_name  \
# index
# 0                ZELLE P2P PAYMENT RECEIVED ON 05/19    \\          None
# 1        Purchase / McDonalds 35052 142-3328095, TN (4633)          None
# 2        Purchase / McDonalds 35052 142-3328095, TN (4633)          None
# 3                                   Transfer from Cash App          None
# 4        POS Withdrawal (FIS) Q NAILS Q NAILS NEWPORT T...          None
# ...                                                    ...           ...
# 1170552                             Cash App*Anthony Cenic          None
# 1170554  Point Of Sale Withdrawal 445488848992 DD DOORD...          None
# 1170555                  Transfer to Chime Savings Account          None
# 1170556                Transfer from Chime Savings Account          None
# 1170557  Point Of Sale Withdrawal - WALGREENS STORE 160...          None
#
#         merchant_name_plaid transaction_type_plaid counterparty_name  ...  \
# index                                                                 ...
# 0                      None                special             Zelle  ...
# 1                      None                  place       McDonald''s  ...
# 2                      None                  place       McDonald''s  ...
# 3                      None                special          Cash App  ...
# 4                      None                  place           Q Nails  ...
# ...                     ...                    ...               ...  ...
# 1170552                None                special          Cash App  ...
# 1170554                None                  place         Mamichuyt  ...
# 1170555                None                special             Chime  ...
# 1170556                None                special             Chime  ...
# 1170557                None                  place         Walgreens  ...
#
#         payment_method payment_processor_method     city region country  \
# index
# 0
# 1
# 2
# 3
# 4                                                Newport     TN
# ...                ...                      ...      ...    ...     ...
# 1170552
# 1170554                                                      CA      US
# 1170555
# 1170556
# 1170557                                            Miami     FL      US
#
#          status decline_code  \
# index
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
# ...         ...          ...
# 1170552    None
# 1170554    None
# 1170555    None
# 1170556    None
# 1170557    None
#
#                       login_provider_additional_attributes  \
# index
# 0        {"datetime": null, "location": {"lat": null, "...
# 1        {"datetime": null, "location": {"lat": null, "...
# 2        {"datetime": null, "location": {"lat": null, "...
# 3        {"datetime": null, "location": {"lat": null, "...
# 4        {"datetime": null, "location": {"lat": null, "...
# ...                                                    ...
# 1170552  {"datetime": "2024-05-20T19:38:03.000Z", "loca...
# 1170554  {"datetime": null, "location": {"lat": null, "...
# 1170555  {"datetime": "2024-05-20T19:11:52.000Z", "loca...
# 1170556  {"datetime": "2024-05-20T20:06:53.000Z", "loca...
# 1170557  {"datetime": null, "location": {"lat": 25.6837...
#
#         merchant_name_combined Chime in descr
# index
# 0                        Zelle          False
# 1                  McDonald''s          False
# 2                  McDonald''s          False
# 3                     Cash App          False
# 4                      Q Nails          False
# ...                        ...            ...
# 1170552               Cash App          False
# 1170554              Mamichuyt          False
# 1170555                  Chime           True
# 1170556                  Chime           True
# 1170557              Walgreens          False
#
# [956812 rows x 30 columns]

# %%
df_trans_cln3.to_parquet()
