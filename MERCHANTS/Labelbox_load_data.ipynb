# %%
# import libraries
import boto3
import pandas as pd
from botocore.exceptions import ClientError
from io import StringIO

# Set the values
bucket_name = 'name of the bucket'
key = 'key value'

# user function;
def read_file(bucket, key_value):
    try:
        s3 = boto3.client('s3')
        obj = s3.get_object(Bucket=bucket_name, Key=key)
        df = pd.read_csv(obj['Body'])
        return df
    except ClientError as ex:
        if ex.response['Error']['Code'] == 'NoSuchKey':
            print("Key doesn't match. Please check the key value entered.")

def read_csv_froms3(bucket_name, object_key):
    clients3 = boto3.client('s3')
    csv_obj = clients3.get_object(Bucket=bucket_name, Key=object_key)
    body = csv_obj['Body']
    csv_string = body.read().decode('utf-8')

    df = pd.read_csv(StringIO(csv_string))
    return df

# %%
# path = "s3://cleo-data-science/transaction_enrichment/experimental_data/transactions__240425_141648"
# df = read_from_s3(path)
# df.head()

# %%
bucket_name = "cleo-data-science"
object_key = "transaction_enrichment/for_labelbox_annotations/mass_annotations_t1.csv"

data = read_csv_froms3(bucket_name, object_key)

# %%
data.head()
# Out:
#    Unnamed: 0          id  total_count Transaction category V1  \
# 0      210449  9073659823            4                   Bills
# 1       57152  9066406227            1                   Bills
# 2       37959  9077359191            1                   Bills
# 3       68310  9073724257            2                   Bills
# 4      166428  9065115628            1                   Bills
#
#   Transaction category V2 Transaction category V2 for Income  \
# 0               Groceries                                NaN
# 1        General services                                NaN
# 2                    Rent                                NaN
# 3                Mortgage                                NaN
# 4       Utilities & Bills                                NaN
#
#          Merchant Name Transfer counterparty name             Date Direction  \
# 0               Klarna                        NaN  2024-03-01, Fri       Out
# 1    Henderson Storage                        NaN  2024-03-01, Fri       Out
# 2                  NaN                        NaN  2024-03-01, Fri       Out
# 3  Carrington Mortgage                        NaN  2024-03-01, Fri       Out
# 4        Payless Power                        NaN  2024-02-29, Thu       Out
#
#    ...                                      Description 1  \
# 0  ...       POS/Check Card Withdrawal / Klarna*instacart
# 1  ...                                  Henderson Storage
# 2  ...                                    YSI*VILLETTA AP
# 3  ...  Withdrawal CARRINGTON MTG / TYPE: MTG PYMT CO:...
# 4  ...  Debit: Signature purchase from 17-8031856498 P...
#
#                                        Description 2  \
# 0  POS/Check Card Withdrawal / Klarna*instacart C...
# 1                                  Henderson Storage
# 2                                    YSI*VILLETTA AP
# 3  Withdrawal CARRINGTON MTG / TYPE: MTG PYMT CO:...
# 4  Debit: Signature purchase from 17-8031856498 P...
#
#        Additional Merchant Name Original company name Payee Payer  \
# 0                        Klarna                   NaN   NaN   NaN
# 1             Henderson Storage     Henderson Storage   NaN   NaN
# 2                   Villetta Ap                   NaN   NaN   NaN
# 3  Carrington Mortgage Services                   NaN   NaN   NaN
# 4                 Payless Power                   NaN   NaN   NaN
#
#   Payment channel                                           Location  \
# 0           other  {'city': 'Columbus', 'region': 'OH', 'country'...
# 1        in store                                                NaN
# 2        in store                                                NaN
# 3           other                                                NaN
# 4          online                                                NaN
#
#                                 Original Description  \
# 0  POS/Check Card Withdrawal / Klarna*instacart C...
# 1                                  Henderson Storage
# 2                                    YSI*VILLETTA AP
# 3  Withdrawal CARRINGTON MTG / TYPE: MTG PYMT CO:...
# 4  Debit: Signature purchase from 17-8031856498 P...
#
#   Transfer counterparty name ISNA
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
#
# [5 rows x 22 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'total_count', 'Transaction category V1',
#        'Transaction category V2', 'Transaction category V2 for Income',
#        'Merchant Name', 'Transfer counterparty name', 'Date', 'Direction',
#        'Amount', 'Currency code', 'Description 1', 'Description 2',
#        'Additional Merchant Name', 'Original company name', 'Payee', 'Payer',
#        'Payment channel', 'Location', 'Original Description',
#        'Transfer counterparty name ISNA'],
#       dtype='object')

# %%
data.shape
# Out:
# (10002, 22)

# %%
print(data[~data['Additional Merchant Name'].isnull()].shape)
print(data[~data['Transaction category V1'].isnull()].shape)
print(data[~data['Transaction category V2'].isnull()].shape)
print(data[~data['Transaction category V2 for Income'].isnull()].shape)
# Out:
# (7572, 22)
# (9373, 22)
# (8288, 22)
# (1517, 22)

# %%
data = data[~data['Additional Merchant Name'].isnull()]
data.shape
# Out:
# (7572, 22)

# %%
data.head()
# Out:
#    Unnamed: 0          id  total_count Transaction category V1  \
# 0      210449  9073659823            4                   Bills
# 1       57152  9066406227            1                   Bills
# 2       37959  9077359191            1                   Bills
# 3       68310  9073724257            2                   Bills
# 4      166428  9065115628            1                   Bills
#
#   Transaction category V2 Transaction category V2 for Income  \
# 0               Groceries                                NaN
# 1        General services                                NaN
# 2                    Rent                                NaN
# 3                Mortgage                                NaN
# 4       Utilities & Bills                                NaN
#
#          Merchant Name Transfer counterparty name             Date Direction  \
# 0               Klarna                        NaN  2024-03-01, Fri       Out
# 1    Henderson Storage                        NaN  2024-03-01, Fri       Out
# 2                  NaN                        NaN  2024-03-01, Fri       Out
# 3  Carrington Mortgage                        NaN  2024-03-01, Fri       Out
# 4        Payless Power                        NaN  2024-02-29, Thu       Out
#
#    ...                                      Description 1  \
# 0  ...       POS/Check Card Withdrawal / Klarna*instacart
# 1  ...                                  Henderson Storage
# 2  ...                                    YSI*VILLETTA AP
# 3  ...  Withdrawal CARRINGTON MTG / TYPE: MTG PYMT CO:...
# 4  ...  Debit: Signature purchase from 17-8031856498 P...
#
#                                        Description 2  \
# 0  POS/Check Card Withdrawal / Klarna*instacart C...
# 1                                  Henderson Storage
# 2                                    YSI*VILLETTA AP
# 3  Withdrawal CARRINGTON MTG / TYPE: MTG PYMT CO:...
# 4  Debit: Signature purchase from 17-8031856498 P...
#
#        Additional Merchant Name Original company name Payee Payer  \
# 0                        Klarna                   NaN   NaN   NaN
# 1             Henderson Storage     Henderson Storage   NaN   NaN
# 2                   Villetta Ap                   NaN   NaN   NaN
# 3  Carrington Mortgage Services                   NaN   NaN   NaN
# 4                 Payless Power                   NaN   NaN   NaN
#
#   Payment channel                                           Location  \
# 0           other  {'city': 'Columbus', 'region': 'OH', 'country'...
# 1        in store                                                NaN
# 2        in store                                                NaN
# 3           other                                                NaN
# 4          online                                                NaN
#
#                                 Original Description  \
# 0  POS/Check Card Withdrawal / Klarna*instacart C...
# 1                                  Henderson Storage
# 2                                    YSI*VILLETTA AP
# 3  Withdrawal CARRINGTON MTG / TYPE: MTG PYMT CO:...
# 4  Debit: Signature purchase from 17-8031856498 P...
#
#   Transfer counterparty name ISNA
# 0                            True
# 1                            True
# 2                            True
# 3                            True
# 4                            True
#
# [5 rows x 22 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'total_count', 'Transaction category V1',
#        'Transaction category V2', 'Transaction category V2 for Income',
#        'Merchant Name', 'Transfer counterparty name', 'Date', 'Direction',
#        'Amount', 'Currency code', 'Description 1', 'Description 2',
#        'Additional Merchant Name', 'Original company name', 'Payee', 'Payer',
#        'Payment channel', 'Location', 'Original Description',
#        'Transfer counterparty name ISNA'],
#       dtype='object')

# %% [markdown]
# %md
# ### LabelBox

# %%
# %pip install "labelbox[data]"
# %pip install labelbox --upgrade
# Out:
# Requirement already satisfied: labelbox[data] in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (3.69.1)
# Requirement already satisfied: geojson>=3.1.0 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (3.1.0)
# Requirement already satisfied: google-api-core>=1.22.1 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (2.19.0)
# Requirement already satisfied: pydantic>=1.8 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (2.7.1)
# Requirement already satisfied: python-dateutil<2.9.0,>=2.8.2 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (2.8.2)
# Requirement already satisfied: requests>=2.22.0 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (2.31.0)
# Requirement already satisfied: strenum>=0.4.15 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (0.4.15)
# Requirement already satisfied: tqdm>=4.66.2 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (4.66.4)
# Requirement already satisfied: imagesize>=1.4.1 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (1.4.1)
# Requirement already satisfied: numpy>=1.24.4 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (1.26.4)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (4.9.0.80)
# Requirement already satisfied: pillow>=10.2.0 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (10.3.0)
# Requirement already satisfied: pygeotile>=1.0.6 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (1.0.6)
# Requirement already satisfied: pyproj>=3.5.0 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (3.6.1)
# Requirement already satisfied: shapely>=2.0.3 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (2.0.4)
# Requirement already satisfied: typeguard>=4.1.5 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (4.2.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox[data]) (4.11.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-api-core>=1.22.1->labelbox[data]) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-api-core>=1.22.1->labelbox[data]) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-api-core>=1.22.1->labelbox[data]) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-api-core>=1.22.1->labelbox[data]) (2.29.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from pydantic>=1.8->labelbox[data]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from pydantic>=1.8->labelbox[data]) (2.18.2)
# Requirement already satisfied: certifi in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from pyproj>=3.5.0->labelbox[data]) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from python-dateutil<2.9.0,>=2.8.2->labelbox[data]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from requests>=2.22.0->labelbox[data]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from requests>=2.22.0->labelbox[data]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from requests>=2.22.0->labelbox[data]) (2.2.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.22.1->labelbox[data]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.22.1->labelbox[data]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.22.1->labelbox[data]) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.22.1->labelbox[data]) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: labelbox in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (3.69.1)
# Requirement already satisfied: geojson>=3.1.0 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox) (3.1.0)
# Requirement already satisfied: google-api-core>=1.22.1 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox) (2.19.0)
# Requirement already satisfied: pydantic>=1.8 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox) (2.7.1)
# Requirement already satisfied: python-dateutil<2.9.0,>=2.8.2 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox) (2.8.2)
# Requirement already satisfied: requests>=2.22.0 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox) (2.31.0)
# Requirement already satisfied: strenum>=0.4.15 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox) (0.4.15)
# Requirement already satisfied: tqdm>=4.66.2 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from labelbox) (4.66.4)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-api-core>=1.22.1->labelbox) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-api-core>=1.22.1->labelbox) (4.25.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-api-core>=1.22.1->labelbox) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-api-core>=1.22.1->labelbox) (2.29.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from pydantic>=1.8->labelbox) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from pydantic>=1.8->labelbox) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from pydantic>=1.8->labelbox) (4.11.0)
# Requirement already satisfied: six>=1.5 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from python-dateutil<2.9.0,>=2.8.2->labelbox) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from requests>=2.22.0->labelbox) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from requests>=2.22.0->labelbox) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from requests>=2.22.0->labelbox) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from requests>=2.22.0->labelbox) (2024.2.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.22.1->labelbox) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.22.1->labelbox) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.22.1->labelbox) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core>=1.22.1->labelbox) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import uuid
import os
import labelbox as lb
#client = lb.Client(os.environ['LABEL_BOX_API_KEY'])
client = lb.Client(api_key="eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..FLbe16iGBRMytAazaPS5zP_JVajjESBPLulAmeaD8fw")
# PROJECT_ID = 'cltctguq201bt07sdhaghb6n8'
PROJECT_ID = 'cltzovsyv014f07xrgl7tb6w7'
project = client.get_project(PROJECT_ID)
# Out:
# /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages/labelbox/schema/export_task.py:119: UserWarning: JSON converter is deprecated and will be removed in a future release
#   warnings.warn("JSON converter is deprecated and will be removed in a future release")

# %% [markdown]
# ### Load ontology of the project

# %%
ontology =list(client.get_ontologies(name_contains='Enrich'))[0]

# %%
ontology
# Out:
# <Ontology ID: cltzouqeq0586070vb07450se>

# %%
ontology_keys = {}
ontology_fids = {}
ontology_ids = {}
for o in ontology.classifications():
    ontology_keys[o.name] = {option.value:option.feature_schema_id for option in o.options}
    ontology_fids[o.name] = o.feature_schema_id
    ontology_ids[o.name] = o.schema_id

# %%
ontology_keys.keys()
# Out:
# dict_keys(['transaction_category_v_1', 'transaction_category_v_2', 'transaction_category_v_2_for_income', 'merchant_name', 'merchant_website', 'transfer_counterpart_name', 'payment_processor', 'comment'])

# %%
{k: len(v)for k, v in ontology_keys.items()}
# Out:
# {'transaction_category_v_1': 15,
#  'transaction_category_v_2': 36,
#  'transaction_category_v_2_for_income': 11,
#  'merchant_name': 0,
#  'merchant_website': 0,
#  'transfer_counterpart_name': 0,
#  'payment_processor': 0,
#  'comment': 0}

# %% [markdown]
# # Prepare dataset

# %%
import re

import labelbox.data.annotation_types as lb_types
import pandas as pd


pd.set_option('display.max_colwidth', None)


columns_labels = ['Transaction category V1',
       'Transaction category V2', 'Transaction category V2 for Income',
       'Merchant Name', 'Transfer counterparty name']
columns_info = ['Date', 'Direction',
       'Amount', 'Currency code', 'Original Description',
       'Extracted Merchant Name', 'Payee', 'Payer',
       'Payment channel', 'Location']
columns_link = ['Original Description', 'Extracted Merchant Name',]


# Prepare data info
def build_link(x, google_search_link = "https://www.google.com/search?q="):
    return google_search_link+ "+".join(x.strip().split(" "))


def prepare_row(i, row):
    unique_links = set()
    links = []
    for col in columns_link:
        if pd.notnull(row[col]):
            link = build_link(row[col])
            if link not in unique_links:
                links.append((build_link(row[col]), col))
                unique_links.add(link)
    return {
        "row_data": row.fillna('').to_string() ,
        "global_key": i,
        "media_type": "TEXT",
        "attachments": [{"type": "RAW_TEXT", "value": link, "name": name} for link, name in links]
      }


# Prepare annotations
def prepare_string_option(x):
    if pd.notnull(x):
        return x.lower().replace(' ','_').replace('_&','')
    return None


def prepare_string(x):
    if pd.notnull(x):
        return x
    return None       


def get_annotations(row):
    annotations = []
    
    x = prepare_string_option(row['Transaction category V1'])
    if pd.notnull(x):        
        annotations.append(
            lb_types.ClassificationAnnotation(
            feature_schema_id=ontology_fids["transaction_category_v_1"],
            schema_id=ontology_ids["transaction_category_v_1"],
            value=lb_types.Radio(answer=lb_types.ClassificationAnswer(
                feature_schema_id=ontology_keys["transaction_category_v_1"][x]
            ))
        ))

    x = prepare_string_option(row['Transaction category V2'])
    if pd.notnull(x):        
         annotations.append(
            lb_types.ClassificationAnnotation(
            feature_schema_id=ontology_fids["transaction_category_v_2"],
            schema_id=ontology_ids["transaction_category_v_2"],
            value=lb_types.Radio(answer=lb_types.ClassificationAnswer(
                feature_schema_id=ontology_keys["transaction_category_v_2"][x]
            ))
        ))
        
    x = prepare_string_option(row['Transaction category V2 for Income'])
    if pd.notnull(x):    
        annotations.append(
            lb_types.ClassificationAnnotation(
            feature_schema_id=ontology_fids["transaction_category_v_2_for_income"],
            schema_id=ontology_ids["transaction_category_v_2_for_income"],
            value=lb_types.Radio(answer=lb_types.ClassificationAnswer(
                feature_schema_id=ontology_keys["transaction_category_v_2_for_income"][x]
            ))
        ))

    x = prepare_string(row['Merchant Name'])
    if pd.notnull(x):                  
        annotations.append(
            lb_types.ClassificationAnnotation(
            feature_schema_id=ontology_fids["merchant_name"],
            schema_id=ontology_ids["merchant_name"],
            value=lb_types.Text(answer=x)
        ))
        
    x = prepare_string(row['Transfer counterparty name'])
    if pd.notnull(x):        
        annotations.append(
            lb_types.ClassificationAnnotation(
            feature_schema_id=ontology_fids["transfer_counterpart_name"],
            schema_id=ontology_ids["transfer_counterpart_name"],
            value=lb_types.Text(answer=x)
        ))
    
    return annotations

# %%
data['Original Description'] = data[['Description 1', 'Description 2']].apply(lambda x: x['Description 2'] if pd.notnull(x['Description 2']) else x['Description 1'], axis = 1)
data['Extracted Merchant Name'] = data['Additional Merchant Name']
data.set_index('id', inplace=True)

# %%
data
# Out:
#             Unnamed: 0  total_count Transaction category V1  \
# id
# 9073659823      210449            4                   Bills
# 9066406227       57152            1                   Bills
# 9077359191       37959            1                   Bills
# 9073724257       68310            2                   Bills
# 9065115628      166428            1                   Bills
# ...                ...          ...                     ...
# 9069741929      178987            1                 General
# 9078990605      257543            1                Shopping
# 9068276728       67271            1        Recurring Income
# 9066221568       37047            1                  Income
# 9064731751       14954            2                    Cash
#
#            Transaction category V2 Transaction category V2 for Income  \
# id
# 9073659823               Groceries                                NaN
# 9066406227        General services                                NaN
# 9077359191                    Rent                                NaN
# 9073724257                Mortgage                                NaN
# 9065115628       Utilities & Bills                                NaN
# ...                            ...                                ...
# 9069741929                     NaN                       Unemployment
# 9078990605                     NaN                       Unemployment
# 9068276728                     NaN                       Unemployment
# 9066221568                     NaN                            Pension
# 9064731751                     NaN                            Pension
#
#                           Merchant Name    Transfer counterparty name  \
# id
# 9073659823                       Klarna                           NaN
# 9066406227            Henderson Storage                           NaN
# 9077359191                          NaN                           NaN
# 9073724257          Carrington Mortgage                           NaN
# 9065115628                Payless Power                           NaN
# ...                                 ...                           ...
# 9069741929  Wisconsin Dwd Ui Ui Payment  Wisconsin Dwd Ui, Ui Payment
# 9078990605                     Afterpay                           NaN
# 9068276728                   Mn Ui Fund                           NaN
# 9066221568                          NaN                           NaN
# 9064731751     Ssi Treas 310 Xxsupp Sec                           NaN
#
#                        Date Direction   Amount  ...  \
# id                                              ...
# 9073659823  2024-03-01, Fri       Out    17.29  ...
# 9066406227  2024-03-01, Fri       Out   200.90  ...
# 9077359191  2024-03-01, Fri       Out  1547.69  ...
# 9073724257  2024-03-01, Fri       Out   344.68  ...
# 9065115628  2024-02-29, Thu       Out    40.00  ...
# ...                     ...       ...      ...  ...
# 9069741929  2024-03-01, Fri       Out   100.00  ...
# 9078990605  2024-03-01, Fri       Out    24.98  ...
# 9068276728  2024-03-01, Fri       Out   200.00  ...
# 9066221568  2024-03-01, Fri        In    25.52  ...
# 9064731751  2024-03-01, Fri       Out   534.37  ...
#
#                                                                                                  Description 2  \
# id
# 9073659823                                          POS/Check Card Withdrawal / Klarna*instacart Columbus OHUS
# 9066406227                                                                                   Henderson Storage
# 9077359191                                                                                     YSI*VILLETTA AP
# 9073724257                                       Withdrawal CARRINGTON MTG / TYPE: MTG PYMT CO: CARRINGTON MTG
# 9065115628  Debit: Signature purchase from 17-8031856498 PAYLESS POWER FORT WORTH TX US 56498229 17-8031856498
# ...                                                                                                        ...
# 9069741929                                                          Direct Debit: Wisconsin Dwd Ui, Ui Payment
# 9078990605                                          Recur Payment CA AFTERPAY.COM Afterpay UI SEQ# XX9449 5762
# 9068276728                                                                              MN UI Fund, UI BENEFIT
# 9066221568                                                                            FROM Oportun, Retirement
# 9064731751                                                     COMPANY NAME:SSI TREAS 310 TRAN DESC:XXSUPP SEC
#
#                 Additional Merchant Name         Original company name  \
# id
# 9073659823                        Klarna                           NaN
# 9066406227             Henderson Storage             Henderson Storage
# 9077359191                   Villetta Ap                           NaN
# 9073724257  Carrington Mortgage Services                           NaN
# 9065115628                 Payless Power                           NaN
# ...                                  ...                           ...
# 9069741929           Wisconsin Dwd Ui Ui  Wisconsin Dwd Ui, Ui Payment
# 9078990605                      AfterPay                      Afterpay
# 9068276728         Mn Ui Fund Ui Benefit                           NaN
# 9066221568             Oportun Financial                           NaN
# 9064731751                     Ssi Treas                           NaN
#
#                                    Payee Payer Payment channel  \
# id
# 9073659823                           NaN   NaN           other
# 9066406227                           NaN   NaN        in store
# 9077359191                           NaN   NaN        in store
# 9073724257                           NaN   NaN           other
# 9065115628                           NaN   NaN          online
# ...                                  ...   ...             ...
# 9069741929  Wisconsin Dwd Ui, Ui Payment   NaN        in store
# 9078990605                           NaN   NaN           other
# 9068276728                           NaN   NaN        in store
# 9066221568                           NaN   NaN           other
# 9064731751                           NaN   NaN        in store
#
#                                                          Location  \
# id
# 9073659823  {'city': 'Columbus', 'region': 'OH', 'country': 'US'}
# 9066406227                                                    NaN
# 9077359191                                                    NaN
# 9073724257                                                    NaN
# 9065115628                                                    NaN
# ...                                                           ...
# 9069741929                                                    NaN
# 9078990605                                                    NaN
# 9068276728                                                    NaN
# 9066221568                                                    NaN
# 9064731751                                                    NaN
#
#                                                                                           Original Description  \
# id
# 9073659823                                          POS/Check Card Withdrawal / Klarna*instacart Columbus OHUS
# 9066406227                                                                                   Henderson Storage
# 9077359191                                                                                     YSI*VILLETTA AP
# 9073724257                                       Withdrawal CARRINGTON MTG / TYPE: MTG PYMT CO: CARRINGTON MTG
# 9065115628  Debit: Signature purchase from 17-8031856498 PAYLESS POWER FORT WORTH TX US 56498229 17-8031856498
# ...                                                                                                        ...
# 9069741929                                                          Direct Debit: Wisconsin Dwd Ui, Ui Payment
# 9078990605                                          Recur Payment CA AFTERPAY.COM Afterpay UI SEQ# XX9449 5762
# 9068276728                                                                              MN UI Fund, UI BENEFIT
# 9066221568                                                                            FROM Oportun, Retirement
# 9064731751                                                     COMPANY NAME:SSI TREAS 310 TRAN DESC:XXSUPP SEC
#
#            Transfer counterparty name ISNA       Extracted Merchant Name
# id
# 9073659823                            True                        Klarna
# 9066406227                            True             Henderson Storage
# 9077359191                            True                   Villetta Ap
# 9073724257                            True  Carrington Mortgage Services
# 9065115628                            True                 Payless Power
# ...                                    ...                           ...
# 9069741929                           False           Wisconsin Dwd Ui Ui
# 9078990605                            True                      AfterPay
# 9068276728                            True         Mn Ui Fund Ui Benefit
# 9066221568                            True             Oportun Financial
# 9064731751                            True                     Ssi Treas
#
# [7572 rows x 22 columns]

# %%
data.loc[9073659823]
# Out:
# Unnamed: 0                                                                                210449
# total_count                                                                                    4
# Transaction category V1                                                                    Bills
# Transaction category V2                                                                Groceries
# Transaction category V2 for Income                                                           NaN
# Merchant Name                                                                             Klarna
# Transfer counterparty name                                                                   NaN
# Date                                                                             2024-03-01, Fri
# Direction                                                                                    Out
# Amount                                                                                     17.29
# Currency code                                                                                USD
# Description 1                                       POS/Check Card Withdrawal / Klarna*instacart
# Description 2                         POS/Check Card Withdrawal / Klarna*instacart Columbus OHUS
# Additional Merchant Name                                                                  Klarna
# Original company name                                                                        NaN
# Payee                                                                                        NaN
# Payer                                                                                        NaN
# Payment channel                                                                            other
# Location                                   {'city': 'Columbus', 'region': 'OH', 'country': 'US'}
# Original Description                  POS/Check Card Withdrawal / Klarna*instacart Columbus OHUS
# Transfer counterparty name ISNA                                                             True
# Extracted Merchant Name                                                                   Klarna
# Name: 9073659823, dtype: object

# %%
data[['Original Description','Merchant Name','Extracted Merchant Name', 'Transaction category V1',
       'Transaction category V2', 'Transaction category V2 for Income']]
# Out:
#                                                                                           Original Description  \
# id
# 9073659823                                          POS/Check Card Withdrawal / Klarna*instacart Columbus OHUS
# 9066406227                                                                                   Henderson Storage
# 9077359191                                                                                     YSI*VILLETTA AP
# 9073724257                                       Withdrawal CARRINGTON MTG / TYPE: MTG PYMT CO: CARRINGTON MTG
# 9065115628  Debit: Signature purchase from 17-8031856498 PAYLESS POWER FORT WORTH TX US 56498229 17-8031856498
# ...                                                                                                        ...
# 9069741929                                                          Direct Debit: Wisconsin Dwd Ui, Ui Payment
# 9078990605                                          Recur Payment CA AFTERPAY.COM Afterpay UI SEQ# XX9449 5762
# 9068276728                                                                              MN UI Fund, UI BENEFIT
# 9066221568                                                                            FROM Oportun, Retirement
# 9064731751                                                     COMPANY NAME:SSI TREAS 310 TRAN DESC:XXSUPP SEC
#
#                           Merchant Name       Extracted Merchant Name  \
# id
# 9073659823                       Klarna                        Klarna
# 9066406227            Henderson Storage             Henderson Storage
# 9077359191                          NaN                   Villetta Ap
# 9073724257          Carrington Mortgage  Carrington Mortgage Services
# 9065115628                Payless Power                 Payless Power
# ...                                 ...                           ...
# 9069741929  Wisconsin Dwd Ui Ui Payment           Wisconsin Dwd Ui Ui
# 9078990605                     Afterpay                      AfterPay
# 9068276728                   Mn Ui Fund         Mn Ui Fund Ui Benefit
# 9066221568                          NaN             Oportun Financial
# 9064731751     Ssi Treas 310 Xxsupp Sec                     Ssi Treas
#
#            Transaction category V1 Transaction category V2  \
# id
# 9073659823                   Bills               Groceries
# 9066406227                   Bills        General services
# 9077359191                   Bills                    Rent
# 9073724257                   Bills                Mortgage
# 9065115628                   Bills       Utilities & Bills
# ...                            ...                     ...
# 9069741929                 General                     NaN
# 9078990605                Shopping                     NaN
# 9068276728        Recurring Income                     NaN
# 9066221568                  Income                     NaN
# 9064731751                    Cash                     NaN
#
#            Transaction category V2 for Income
# id
# 9073659823                                NaN
# 9066406227                                NaN
# 9077359191                                NaN
# 9073724257                                NaN
# 9065115628                                NaN
# ...                                       ...
# 9069741929                       Unemployment
# 9078990605                       Unemployment
# 9068276728                       Unemployment
# 9066221568                            Pension
# 9064731751                            Pension
#
# [7572 rows x 6 columns]

# %%
data = data[~data['Extracted Merchant Name'].isnull()]

# %%
data.shape
# Out:
# (7572, 22)

# %%
info = {i: prepare_row(i, row) for i, row in data[columns_info].iterrows()}

# %%
info
# Out:
# {9073659823: {'row_data': "Date                                                                  2024-03-01, Fri\nDirection                                                                         Out\nAmount                                                                          17.29\nCurrency code                                                                     USD\nOriginal Description       POS/Check Card Withdrawal / Klarna*instacart Columbus OHUS\nExtracted Merchant Name                                                        Klarna\nPayee                                                                                \nPayer                                                                                \nPayment channel                                                                 other\nLocation                        {'city': 'Columbus', 'region': 'OH', 'country': 'US'}",
#   'global_key': 9073659823,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=POS/Check+Card+Withdrawal+/+Klarna*instacart+Columbus+OHUS',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Klarna',
#     'name': 'Extracted Merchant Name'}]},
#  9066406227: {'row_data': 'Date                         2024-03-01, Fri\nDirection                                Out\nAmount                                 200.9\nCurrency code                            USD\nOriginal Description       Henderson Storage\nExtracted Merchant Name    Henderson Storage\nPayee                                       \nPayer                                       \nPayment channel                     in store\nLocation                                    ',
#   'global_key': 9066406227,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Henderson+Storage',
#     'name': 'Original Description'}]},
#  9077359191: {'row_data': 'Date                       2024-03-01, Fri\nDirection                              Out\nAmount                             1547.69\nCurrency code                          USD\nOriginal Description       YSI*VILLETTA AP\nExtracted Merchant Name        Villetta Ap\nPayee                                     \nPayer                                     \nPayment channel                   in store\nLocation                                  ',
#   'global_key': 9077359191,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=YSI*VILLETTA+AP',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Villetta+Ap',
#     'name': 'Extracted Merchant Name'}]},
#  9073724257: {'row_data': 'Date                                                                     2024-03-01, Fri\nDirection                                                                            Out\nAmount                                                                            344.68\nCurrency code                                                                        USD\nOriginal Description       Withdrawal CARRINGTON MTG / TYPE: MTG PYMT CO: CARRINGTON MTG\nExtracted Merchant Name                                     Carrington Mortgage Services\nPayee                                                                                   \nPayer                                                                                   \nPayment channel                                                                    other\nLocation                                                                                ',
#   'global_key': 9073724257,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Withdrawal+CARRINGTON+MTG+/+TYPE:+MTG+PYMT+CO:+CARRINGTON+MTG',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Carrington+Mortgage+Services',
#     'name': 'Extracted Merchant Name'}]},
#  9065115628: {'row_data': 'Date                                                                                                          2024-02-29, Thu\nDirection                                                                                                                 Out\nAmount                                                                                                                   40.0\nCurrency code                                                                                                             USD\nOriginal Description       Debit: Signature purchase from 17-8031856498 PAYLESS POWER FORT WORTH TX US 56498229 17-8031856498\nExtracted Merchant Name                                                                                         Payless Power\nPayee                                                                                                                        \nPayer                                                                                                                        \nPayment channel                                                                                                        online\nLocation                                                                                                                     ',
#   'global_key': 9065115628,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Debit:+Signature+purchase+from+17-8031856498+PAYLESS+POWER+FORT+WORTH+TX+US+56498229+17-8031856498',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Payless+Power',
#     'name': 'Extracted Merchant Name'}]},
#  9070431989: {'row_data': 'Date                       2024-03-01, Fri\nDirection                              Out\nAmount                               19.99\nCurrency code                          USD\nOriginal Description             LUCKYLAND\nExtracted Merchant Name    LuckyLand Slots\nPayee                                     \nPayer                                     \nPayment channel                   in store\nLocation                                  ',
#   'global_key': 9070431989,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=LUCKYLAND',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=LuckyLand+Slots',
#     'name': 'Extracted Merchant Name'}]},
#  9076760467: {'row_data': "Date                                                                                         2024-03-01, Fri\nDirection                                                                                                Out\nAmount                                                                                                 500.0\nCurrency code                                                                                            USD\nOriginal Description                                Withdrawal STCU,207 E HASTINGS         SPOKANE      WAUS\nExtracted Merchant Name                                                                                 Stcu\nPayee                                                                                                       \nPayer                                                                                                       \nPayment channel                                                                                     in store\nLocation                   {'city': 'Spokane', 'region': 'WA', 'address': '207 E Hastings', 'country': 'US'}",
#   'global_key': 9076760467,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Withdrawal+STCU,207+E+HASTINGS+++++++++SPOKANE++++++WAUS',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Stcu',
#     'name': 'Extracted Merchant Name'}]},
#  9071837191: {'row_data': 'Date                                                2024-03-01, Fri\nDirection                                                       Out\nAmount                                                         8.02\nCurrency code                                                   USD\nOriginal Description       ACH Withdrawal - SNAP FINANCE  - PAYMENT\nExtracted Merchant Name                                Snap Finance\nPayee                                                              \nPayer                                                              \nPayment channel                                               other\nLocation                                                           ',
#   'global_key': 9071837191,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=ACH+Withdrawal+-+SNAP+FINANCE++-+PAYMENT',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Snap+Finance',
#     'name': 'Extracted Merchant Name'}]},
#  9074839874: {'row_data': 'Date                              2024-03-01, Fri\nDirection                                     Out\nAmount                                     191.54\nCurrency code                                 USD\nOriginal Description       Southside Electric Coo\nExtracted Merchant Name    Southside Electric Coo\nPayee                                            \nPayer                                            \nPayment channel                          in store\nLocation                                         ',
#   'global_key': 9074839874,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Southside+Electric+Coo',
#     'name': 'Original Description'}]},
#  9073195085: {'row_data': 'Date                                                                           2024-03-01, Fri\nDirection                                                                                  Out\nAmount                                                                                    31.0\nCurrency code                                                                              USD\nOriginal Description       ACH NSF FEE  / In the amount $50.31 POSSIBLE FINANCE %% ACH ECC WEB\nExtracted Merchant Name                                                       Possible Finance\nPayee                                                                                         \nPayer                                                                                         \nPayment channel                                                                          other\nLocation                                                                                      ',
#   'global_key': 9073195085,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=ACH+NSF+FEE++/+In+the+amount+$50.31+POSSIBLE+FINANCE+%%+ACH+ECC+WEB',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Possible+Finance',
#     'name': 'Extracted Merchant Name'}]},
#  9070463829: {'row_data': 'Date                                        2024-03-01, Fri\nDirection                                               Out\nAmount                                               118.27\nCurrency code                                           USD\nOriginal Description       ElkLending 18041848 - 8558773275\nExtracted Merchant Name                          Elklending\nPayee                                                      \nPayer                                                      \nPayment channel                                    in store\nLocation                                                   ',
#   'global_key': 9070463829,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=ElkLending+18041848+-+8558773275',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Elklending',
#     'name': 'Extracted Merchant Name'}]},
#  9069568393: {'row_data': "Date                                                                       2024-03-01, Fri\nDirection                                                                              Out\nAmount                                                                               99.99\nCurrency code                                                                          USD\nOriginal Description       Debit Card purchase PHOENIX PROCESSING SYST 5812 205-8982720 AL\nExtracted Merchant Name                                            Phoenix Processing Syst\nPayee                                                                                     \nPayer                                                                                     \nPayment channel                                                                   in store\nLocation                                                                  {'region': 'AL'}",
#   'global_key': 9069568393,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Debit+Card+purchase+PHOENIX+PROCESSING+SYST+5812+205-8982720+AL',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Phoenix+Processing+Syst',
#     'name': 'Extracted Merchant Name'}]},
#  9074028754: {'row_data': 'Date                       2024-03-01, Fri\nDirection                              Out\nAmount                               10.55\nCurrency code                          USD\nOriginal Description             BIGO LIVE\nExtracted Merchant Name          Bigo Live\nPayee                                     \nPayer                                     \nPayment channel                   in store\nLocation                                  ',
#   'global_key': 9074028754,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=BIGO+LIVE',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Bigo+Live',
#     'name': 'Extracted Merchant Name'}]},
#  9077588705: {'row_data': 'Date                       2024-03-01, Fri\nDirection                              Out\nAmount                               12.79\nCurrency code                          USD\nOriginal Description        The Sauced Pig\nExtracted Merchant Name     The Sauced Pig\nPayee                                     \nPayer                                     \nPayment channel                   in store\nLocation                                  ',
#   'global_key': 9077588705,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=The+Sauced+Pig',
#     'name': 'Original Description'}]},
#  9077122865: {'row_data': "Date                                                                                                           2024-02-29, Thu\nDirection                                                                                                                  Out\nAmount                                                                                                                    25.0\nCurrency code                                                                                                              USD\nOriginal Description       DRAFTKINGS 222 BERKELEY ST FL 5Date 02/29/24 00406070000432671542956Card 4991/Withdrawal Debit Card\nExtracted Merchant Name                                                                                             DraftKings\nPayee                                                                                                                         \nPayer                                                                                                                         \nPayment channel                                                                                                       in store\nLocation                                                                                  {'city': 'Berkeley', 'region': 'FL'}",
#   'global_key': 9077122865,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=DRAFTKINGS+222+BERKELEY+ST+FL+5Date+02/29/24+00406070000432671542956Card+4991/Withdrawal+Debit+Card',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=DraftKings',
#     'name': 'Extracted Merchant Name'}]},
#  9072774235: {'row_data': 'Date                              2024-03-01, Fri\nDirection                                     Out\nAmount                                      100.0\nCurrency code                                 USD\nOriginal Description       CONSOLIDATED COMMUNICA\nExtracted Merchant Name    Consolidated Communica\nPayee                                            \nPayer                                            \nPayment channel                            online\nLocation                                         ',
#   'global_key': 9072774235,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=CONSOLIDATED+COMMUNICA',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Consolidated+Communica',
#     'name': 'Extracted Merchant Name'}]},
#  9077496382: {'row_data': 'Date                                                                                                                                                      2024-03-01, Fri\nDirection                                                                                                                                                             Out\nAmount                                                                                                                                                              14.99\nCurrency code                                                                                                                                                         USD\nOriginal Description       TYPE: Cleo AI ID: 945440567 CO: Cleo AINAME: Latrina SmithEntry Class Code: WEBACH Trace Number: 273976360006574/Withdrawal Electronic Cleo AI\nExtracted Merchant Name                                                                                                                                           Cleo AI\nPayee                                                                                                                                                                    \nPayer                                                                                                                                                                    \nPayment channel                                                                                                                                                     other\nLocation                                                                                                                                                                 ',
#   'global_key': 9077496382,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=TYPE:+Cleo+AI+ID:+945440567+CO:+Cleo+AINAME:+Latrina+SmithEntry+Class+Code:+WEBACH+Trace+Number:+273976360006574/Withdrawal+Electronic+Cleo+AI',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Cleo+AI',
#     'name': 'Extracted Merchant Name'}]},
#  9075601653: {'row_data': 'Date                       2024-03-01, Fri\nDirection                              Out\nAmount                               21.94\nCurrency code                          USD\nOriginal Description        Smokehouse Iii\nExtracted Merchant Name     Smokehouse Iii\nPayee                                     \nPayer                                     \nPayment channel                   in store\nLocation                                  ',
#   'global_key': 9075601653,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Smokehouse+Iii',
#     'name': 'Original Description'}]},
#  9066526207: {'row_data': "Date                                                                    2024-03-01, Fri\nDirection                                                                           Out\nAmount                                                                            120.0\nCurrency code                                                                       USD\nOriginal Description       Allpoint ATM RACETRAC FL -T00 5015 FLORIDA BLVD, BATON ROUGE\nExtracted Merchant Name                                                        RaceTrac\nPayee                                                                                  \nPayer                                                                                  \nPayment channel                                                                in store\nLocation                        {'city': 'Baton Rouge', 'address': '5015 Florida Blvd'}",
#   'global_key': 9066526207,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Allpoint+ATM+RACETRAC+FL+-T00+5015+FLORIDA+BLVD,+BATON+ROUGE',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=RaceTrac',
#     'name': 'Extracted Merchant Name'}]},
#  9076688902: {'row_data': 'Date                       2024-03-01, Fri\nDirection                              Out\nAmount                              103.24\nCurrency code                          USD\nOriginal Description                Sheetz\nExtracted Merchant Name             Sheetz\nPayee                                     \nPayer                                     \nPayment channel                   in store\nLocation                                  ',
#   'global_key': 9076688902,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Sheetz',
#     'name': 'Original Description'}]},
#  9076352656: {'row_data': 'Date                               2024-03-01, Fri\nDirection                                      Out\nAmount                                       22.23\nCurrency code                                  USD\nOriginal Description       Deferit* Spectrum 3 Of4\nExtracted Merchant Name                   Spectrum\nPayee                                             \nPayer                                             \nPayment channel                              other\nLocation                                          ',
#   'global_key': 9076352656,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Deferit*+Spectrum+3+Of4',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Spectrum',
#     'name': 'Extracted Merchant Name'}]},
#  9075368552: {'row_data': 'Date                                                                                                                                            2024-02-29, Thu\nDirection                                                                                                                                                   Out\nAmount                                                                                                                                                     5.41\nCurrency code                                                                                                                                               USD\nOriginal Description       365 MARKET K 888 432-32 TROY MIDate 02/29/24 24013394061000070258635Card 543742RRN 406125000070/Withdrawal Debit Card DEBIT-PURCHASE\nExtracted Merchant Name                                                                                                                      365 Retail Markets\nPayee                                                                                                                                                          \nPayer                                                                                                                                                          \nPayment channel                                                                                                                                        in store\nLocation                                                                                                                                                       ',
#   'global_key': 9075368552,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=365+MARKET+K+888+432-32+TROY+MIDate+02/29/24+24013394061000070258635Card+543742RRN+406125000070/Withdrawal+Debit+Card+DEBIT-PURCHASE',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=365+Retail+Markets',
#     'name': 'Extracted Merchant Name'}]},
#  9076804635: {'row_data': "Date                                                   2024-03-01, Fri\nDirection                                                          Out\nAmount                                                           26.05\nCurrency code                                                      USD\nOriginal Description       POS  CREDITSTRONG-AUSCABANK 000-x0000  TXUS\nExtracted Merchant Name                         Creditstrong-auscabank\nPayee                                                                 \nPayer                                                                 \nPayment channel                                                 online\nLocation                             {'region': 'TX', 'country': 'US'}",
#   'global_key': 9076804635,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=POS++CREDITSTRONG-AUSCABANK+000-x0000++TXUS',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Creditstrong-auscabank',
#     'name': 'Extracted Merchant Name'}]},
#  9078638979: {'row_data': "Date                            2024-03-01, Fri\nDirection                                   Out\nAmount                                    21.76\nCurrency code                               USD\nOriginal Description           Fatcats Surprise\nExtracted Merchant Name                 Fatcats\nPayee                                          \nPayer                                          \nPayment channel                        in store\nLocation                   {'city': 'Surprise'}",
#   'global_key': 9078638979,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Fatcats+Surprise',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Fatcats',
#     'name': 'Extracted Merchant Name'}]},
#  9073266597: {'row_data': "Date                                                                                             2024-03-01, Fri\nDirection                                                                                                    Out\nAmount                                                                                                     67.98\nCurrency code                                                                                                USD\nOriginal Description       Point Of Sale Withdrawal FINGERHUT FETTI PAYMENTS 13300 PIONEER TRAIL    EDEN PRAIRIE\nExtracted Merchant Name                                                                                Fingerhut\nPayee                                                                                                           \nPayer                                                                                                           \nPayment channel                                                                                         in store\nLocation                                              {'city': 'Eden Prairie', 'address': '13300 Pioneer Trail'}",
#   'global_key': 9073266597,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Point+Of+Sale+Withdrawal+FINGERHUT+FETTI+PAYMENTS+13300+PIONEER+TRAIL++++EDEN+PRAIRIE',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Fingerhut',
#     'name': 'Extracted Merchant Name'}]},
#  9078801340: {'row_data': "Date                                                                                                                                        2024-03-01, Fri\nDirection                                                                                                                                               Out\nAmount                                                                                                                                                31.45\nCurrency code                                                                                                                                           USD\nOriginal Description                                                                               POS Signature Debit RENT A CENTER 72 LAFOLLETTE TN #5539\nExtracted Merchant Name                                                                                                                       Rent-A-Center\nPayee                                                                                                                                                      \nPayer                                                                                                                                                      \nPayment channel                                                                                                                                    in store\nLocation                   {'city': 'La Follette', 'region': 'TN', 'address': '2221 Jacksboro Pike Ste A3', 'postal_code': '37766', 'store_number': '5539'}",
#   'global_key': 9078801340,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=POS+Signature+Debit+RENT+A+CENTER+72+LAFOLLETTE+TN+#5539',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Rent-A-Center',
#     'name': 'Extracted Merchant Name'}]},
#  9073926299: {'row_data': 'Date                                                                                                                                         2024-03-01, Fri\nDirection                                                                                                                                                Out\nAmount                                                                                                                                                   5.0\nCurrency code                                                                                                                                            USD\nOriginal Description       Debit: Fee for declined ACH debit on Dec 19, 2023 from STASH CAPITAL (S for ACH because of Insufficient Funds to cover this debit\nExtracted Merchant Name                                                                                                                                Stash\nPayee                                                                                                                                                       \nPayer                                                                                                                                                       \nPayment channel                                                                                                                                        other\nLocation                                                                                                                                                    ',
#   'global_key': 9073926299,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Debit:+Fee+for+declined+ACH+debit+on+Dec+19,+2023+from+STASH+CAPITAL+(S+for+ACH+because+of+Insufficient+Funds+to+cover+this+debit',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Stash',
#     'name': 'Extracted Merchant Name'}]},
#  9079528585: {'row_data': "Date                                         2024-03-02, Sat\nDirection                                                Out\nAmount                                                  4.95\nCurrency code                                            USD\nOriginal Description       DISTROKID EXTRAS DISTROKID.COM NY\nExtracted Merchant Name                     Distrokid Extras\nPayee                                                       \nPayer                                                       \nPayment channel                                       online\nLocation                                    {'region': 'NY'}",
#   'global_key': 9079528585,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=DISTROKID+EXTRAS+DISTROKID.COM+NY',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Distrokid+Extras',
#     'name': 'Extracted Merchant Name'}]},
#  9068338889: {'row_data': 'Date                                                                                            2024-03-01, Fri\nDirection                                                                                                   Out\nAmount                                                                                                    110.0\nCurrency code                                                                                               USD\nOriginal Description       Debit card Withdrawal / Cleo Salary Advance 6051 (2024-02-28) Wilmington DE cleoco01\nExtracted Merchant Name                                                                                    Cleo\nPayee                                                                                                          \nPayer                                                                                                          \nPayment channel                                                                                           other\nLocation                                                                                                       ',
#   'global_key': 9068338889,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Debit+card+Withdrawal+/+Cleo+Salary+Advance+6051+(2024-02-28)+Wilmington+DE+cleoco01',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Cleo',
#     'name': 'Extracted Merchant Name'}]},
#  9070287889: {'row_data': 'Date                                                                                                   2024-03-01, Fri\nDirection                                                                                                          Out\nAmount                                                                                                          225.99\nCurrency code                                                                                                      USD\nOriginal Description       Withdrawal ACH Brigit-com TYPE: PROTECTION ID: 2823136030 CO: Brigit-com NAME: James Kearns\nExtracted Merchant Name                                                                                         Brigit\nPayee                                                                                                                 \nPayer                                                                                                                 \nPayment channel                                                                                                  other\nLocation                                                                                                              ',
#   'global_key': 9070287889,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Withdrawal+ACH+Brigit-com+TYPE:+PROTECTION+ID:+2823136030+CO:+Brigit-com+NAME:+James+Kearns',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Brigit',
#     'name': 'Extracted Merchant Name'}]},
#  9068675895: {'row_data': 'Date                       2024-03-01, Fri\nDirection                              Out\nAmount                               207.8\nCurrency code                          USD\nOriginal Description         SPI NV ENERGY\nExtracted Merchant Name          NV Energy\nPayee                                     \nPayer                                     \nPayment channel                     online\nLocation                                  ',
#   'global_key': 9068675895,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=SPI+NV+ENERGY',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=NV+Energy',
#     'name': 'Extracted Merchant Name'}]},
#  9067956086: {'row_data': 'Date                                                                                                                       2024-03-01, Fri\nDirection                                                                                                                              Out\nAmount                                                                                                                               156.0\nCurrency code                                                                                                                          USD\nOriginal Description       Withdrawal Visa Check Card / EMPOWER ADVANCE EMPOWER.ME CA Date 03/01/24 24011344061000021677534 6051 Card 8613\nExtracted Merchant Name                                                                                                            Empower\nPayee                                                                                                                                     \nPayer                                                                                                                                     \nPayment channel                                                                                                                      other\nLocation                                                                                                                                  ',
#   'global_key': 9067956086,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Withdrawal+Visa+Check+Card+/+EMPOWER+ADVANCE+EMPOWER.ME+CA+Date+03/01/24+24011344061000021677534+6051+Card+8613',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Empower',
#     'name': 'Extracted Merchant Name'}]},
#  9069355291: {'row_data': "Date                                                                                      2024-03-01, Fri\nDirection                                                                                             Out\nAmount                                                                                                9.0\nCurrency code                                                                                         USD\nOriginal Description       Debit: Signature purchase from ZZKTTRWLULRMDDH CLIFFSNOTES HTTPSWWW.CLIF NJ US\nExtracted Merchant Name                                                                       Cliffsnotes\nPayee                                                                                                    \nPayer                                                                                                    \nPayment channel                                                                                    online\nLocation                                                                {'region': 'NJ', 'country': 'US'}",
#   'global_key': 9069355291,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Debit:+Signature+purchase+from+ZZKTTRWLULRMDDH+CLIFFSNOTES+HTTPSWWW.CLIF+NJ+US',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Cliffsnotes',
#     'name': 'Extracted Merchant Name'}]},
#  9076505302: {'row_data': 'Date                                                                                2024-03-01, Fri\nDirection                                                                                       Out\nAmount                                                                                         42.0\nCurrency code                                                                                   USD\nOriginal Description       Point Of Sale Withdrawal ABC*50123-ANYTIME F888-8279262 VAUS No Category\nExtracted Merchant Name                                                             Anytime Fitness\nPayee                                                                                              \nPayer                                                                                              \nPayment channel                                                                              online\nLocation                                                                                           ',
#   'global_key': 9076505302,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Point+Of+Sale+Withdrawal+ABC*50123-ANYTIME+F888-8279262+VAUS+No+Category',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Anytime+Fitness',
#     'name': 'Extracted Merchant Name'}]},
#  9070448922: {'row_data': "Date                                                                                                                         2024-02-29, Thu\nDirection                                                                                                                                Out\nAmount                                                                                                                                 40.07\nCurrency code                                                                                                                            USD\nOriginal Description       Withdrawal Debit Consumer / PELLEGRINO''S OF COLONIE ALBANY NY Date 02/29/24 2 4060900016 4 5499 %% Card 20 #0623\nExtracted Merchant Name                                                                                              Pellegrino's Of Colonie\nPayee                                                                                                                                       \nPayer                                                                                                                                       \nPayment channel                                                                                                                     in store\nLocation                                                                                                  {'city': 'Albany', 'region': 'NY'}",
#   'global_key': 9070448922,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': "https://www.google.com/search?q=Withdrawal+Debit+Consumer+/+PELLEGRINO''S+OF+COLONIE+ALBANY+NY+Date+02/29/24+2+4060900016+4+5499+%%+Card+20+#0623",
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': "https://www.google.com/search?q=Pellegrino's+Of+Colonie",
#     'name': 'Extracted Merchant Name'}]},
#  9077366471: {'row_data': 'Date                                                                                                       2024-03-01, Fri\nDirection                                                                                                              Out\nAmount                                                                                                               35.55\nCurrency code                                                                                                          USD\nOriginal Description       Withdrawal ACH SNAP FINANCE TYPE: PAYMENT ID: 1455176354 CO: SNAP FINANCE Entry Class Code: PPD\nExtracted Merchant Name                                                                                       Snap Finance\nPayee                                                                                                                     \nPayer                                                                                                                     \nPayment channel                                                                                                      other\nLocation                                                                                                                  ',
#   'global_key': 9077366471,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Withdrawal+ACH+SNAP+FINANCE+TYPE:+PAYMENT+ID:+1455176354+CO:+SNAP+FINANCE+Entry+Class+Code:+PPD',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Snap+Finance',
#     'name': 'Extracted Merchant Name'}]},
#  9079133205: {'row_data': 'Date                                                                             2024-03-01, Fri\nDirection                                                                                    Out\nAmount                                                                                    220.95\nCurrency code                                                                                USD\nOriginal Description       WITHDRAWAL AT ATM # BP ATT* BILL PAYMENT 800-331-0500 TX Card 7070   \nExtracted Merchant Name                                                                     AT&T\nPayee                                                                                           \nPayer                                                                                           \nPayment channel                                                                            other\nLocation                                                                                        ',
#   'global_key': 9079133205,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=WITHDRAWAL+AT+ATM+#+BP+ATT*+BILL+PAYMENT+800-331-0500+TX+Card+7070',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=AT&T',
#     'name': 'Extracted Merchant Name'}]},
# ...
#   'global_key': 9071138603,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Debit+Card+Withdrawal+FANDUELSBKPRIMARY+NJ+Date+03/01/24+24492154061719640960168+7801+Card+#4091',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=FanDuel+Sportsbook',
#     'name': 'Extracted Merchant Name'}]},
#  9074632384: {'row_data': "Date                                                                                                        2024-03-01, Fri\nDirection                                                                                                               Out\nAmount                                                                                                                 26.0\nCurrency code                                                                                                           USD\nOriginal Description       Debit Card Withdrawal FANDUELCASPRIMARY NJ Date 03/01/24 24492154061745740581729 7801 Card #6862\nExtracted Merchant Name                                                                                             FanDuel\nPayee                                                                                                                      \nPayer                                                                                                                      \nPayment channel                                                                                                    in store\nLocation                                                                                           {'store_number': '6862'}",
#   'global_key': 9074632384,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Debit+Card+Withdrawal+FANDUELCASPRIMARY+NJ+Date+03/01/24+24492154061745740581729+7801+Card+#6862',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=FanDuel',
#     'name': 'Extracted Merchant Name'}]},
#  9078040998: {'row_data': 'Date                       2024-03-01, Fri\nDirection                              Out\nAmount                                10.0\nCurrency code                          USD\nOriginal Description            Prizepicks\nExtracted Merchant Name         Prizepicks\nPayee                                     \nPayer                                     \nPayment channel                   in store\nLocation                                  ',
#   'global_key': 9078040998,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Prizepicks',
#     'name': 'Original Description'}]},
#  9066872721: {'row_data': 'Date                       2024-03-01, Fri\nDirection                              Out\nAmount                                4.99\nCurrency code                          USD\nOriginal Description           Klar Gaming\nExtracted Merchant Name        Klar Gaming\nPayee                                     \nPayer                                     \nPayment channel                   in store\nLocation                                  ',
#   'global_key': 9066872721,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Klar+Gaming',
#     'name': 'Original Description'}]},
#  9073840478: {'row_data': 'Date                                                                                             2024-03-01, Fri\nDirection                                                                                                    Out\nAmount                                                                                                      4.99\nCurrency code                                                                                                USD\nOriginal Description       Point Of Sale Withdrawal GOOGLE *YouTube Member 1600 Amphitheatre ParkwMountain ViewC\nExtracted Merchant Name                                                                                  YouTube\nPayee                                                                                                           \nPayer                                                                                                           \nPayment channel                                                                                           online\nLocation                                                                                                        ',
#   'global_key': 9073840478,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Point+Of+Sale+Withdrawal+GOOGLE+*YouTube+Member+1600+Amphitheatre+ParkwMountain+ViewC',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=YouTube',
#     'name': 'Extracted Merchant Name'}]},
#  9077146977: {'row_data': 'Date                                                                                                        2024-03-01, Fri\nDirection                                                                                                               Out\nAmount                                                                                                                 39.0\nCurrency code                                                                                                           USD\nOriginal Description       TYPE: CLUB FEES CO: PLANET FITNAME: Adam BingamanEntry Class Code: WEB/Withdrawal ACH PLANET FIT\nExtracted Merchant Name                                                                                      Planet Fitname\nPayee                                                                                                                      \nPayer                                                                                                                      \nPayment channel                                                                                                    in store\nLocation                                                                                                                   ',
#   'global_key': 9077146977,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=TYPE:+CLUB+FEES+CO:+PLANET+FITNAME:+Adam+BingamanEntry+Class+Code:+WEB/Withdrawal+ACH+PLANET+FIT',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Planet+Fitname',
#     'name': 'Extracted Merchant Name'}]},
#  9078248592: {'row_data': 'Date                                2024-03-01, Fri\nDirection                                       Out\nAmount                                        11.99\nCurrency code                                   USD\nOriginal Description       Kindle Unltd*Rw2 Qe7 Wu1\nExtracted Merchant Name               Amazon Kindle\nPayee                                              \nPayer                                              \nPayment channel                            in store\nLocation                                           ',
#   'global_key': 9078248592,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Kindle+Unltd*Rw2+Qe7+Wu1',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Amazon+Kindle',
#     'name': 'Extracted Merchant Name'}]},
#  9071712712: {'row_data': "Date                                                                2024-03-01, Fri\nDirection                                                                       Out\nAmount                                                                         15.0\nCurrency code                                                                   USD\nOriginal Description       Credit or debit card Withdrawal DRAFTKINGS 6179865744 MA\nExtracted Merchant Name                                                  DraftKings\nPayee                                                                              \nPayer                                                                              \nPayment channel                                                              online\nLocation                                                           {'region': 'MA'}",
#   'global_key': 9071712712,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Credit+or+debit+card+Withdrawal+DRAFTKINGS+6179865744+MA',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=DraftKings',
#     'name': 'Extracted Merchant Name'}]},
#  9077892523: {'row_data': "Date                                           2024-03-01, Fri\nDirection                                                  Out\nAmount                                                     9.0\nCurrency code                                              USD\nOriginal Description       DEBIT CARD DRAFTKINGS 6179865744 MA\nExtracted Merchant Name                             DraftKings\nPayee                                                         \nPayer                                                         \nPayment channel                                         online\nLocation                                      {'region': 'MA'}",
#   'global_key': 9077892523,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=DEBIT+CARD+DRAFTKINGS+6179865744+MA',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=DraftKings',
#     'name': 'Extracted Merchant Name'}]},
#  9068406551: {'row_data': "Date                                              2024-03-01, Fri\nDirection                                                     Out\nAmount                                                       30.0\nCurrency code                                                 USD\nOriginal Description       AM BEAUTY INSTITUTE LLC 775-7781862 NV\nExtracted Merchant Name                   Am Beauty Institute LLC\nPayee                                                            \nPayer                                                            \nPayment channel                                            online\nLocation                                         {'region': 'NV'}",
#   'global_key': 9068406551,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=AM+BEAUTY+INSTITUTE+LLC+775-7781862+NV',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Am+Beauty+Institute+LLC',
#     'name': 'Extracted Merchant Name'}]},
#  9073959318: {'row_data': 'Date                                                                                                           2024-03-01, Fri\nDirection                                                                                                                  Out\nAmount                                                                                                                   10.94\nCurrency code                                                                                                              USD\nOriginal Description       POS Withdrawal - Patreon* Membership 600 Townsend  5th FloorInternet     CAUS - Card Ending In 0245\nExtracted Merchant Name                                                                                                Patreon\nPayee                                                                                                                         \nPayer                                                                                                                         \nPayment channel                                                                                                         online\nLocation                                                                                                                      ',
#   'global_key': 9073959318,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=POS+Withdrawal+-+Patreon*+Membership+600+Townsend++5th+FloorInternet+++++CAUS+-+Card+Ending+In+0245',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Patreon',
#     'name': 'Extracted Merchant Name'}]},
#  9073966949: {'row_data': 'Date                           2024-03-01, Fri\nDirection                                  Out\nAmount                                   15.81\nCurrency code                              USD\nOriginal Description       EA  ELECTRONIC ARTS\nExtracted Merchant Name        Electronic Arts\nPayee                                         \nPayer                                         \nPayment channel                       in store\nLocation                                      ',
#   'global_key': 9073966949,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=EA++ELECTRONIC+ARTS',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Electronic+Arts',
#     'name': 'Extracted Merchant Name'}]},
#  9073281880: {'row_data': 'Date                                                                                       2024-03-01, Fri\nDirection                                                                                              Out\nAmount                                                                                               26.98\nCurrency code                                                                                          USD\nOriginal Description       DC Disney Plus 888-9057888 CA Ref:406124000616 Auth:139653 PurchDate:03-01-2024\nExtracted Merchant Name                                                                            Disney+\nPayee                                                                                                     \nPayer                                                                                                     \nPayment channel                                                                                     online\nLocation                                                                                                  ',
#   'global_key': 9073281880,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=DC+Disney+Plus+888-9057888+CA+Ref:406124000616+Auth:139653+PurchDate:03-01-2024',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Disney+',
#     'name': 'Extracted Merchant Name'}]},
#  9077119152: {'row_data': 'Date                              2024-03-02, Sat\nDirection                                     Out\nAmount                                       5.99\nCurrency code                                 USD\nOriginal Description       Peacock 9 E165 Premium\nExtracted Merchant Name                   Peacock\nPayee                                            \nPayer                                            \nPayment channel                            online\nLocation                                         ',
#   'global_key': 9077119152,
#   'media_type': 'TEXT',
#   'attachments': [{'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Peacock+9+E165+Premium',
#     'name': 'Original Description'},
#    {'type': 'RAW_TEXT',
#     'value': 'https://www.google.com/search?q=Peacock',
#     'name': 'Extracted Merchant Name'}]},
#  ...}

# %%
annotations = []
for i, row in data[columns_labels].iterrows():
    annotations.append(
    lb_types.Label(
        data=lb_types.TextData(global_key=i),
        annotations=get_annotations(row),
    )
)
annotations[0].annotations[0]
# Out:
# /Users/claracastellanos/CODES/.venvdataexp/lib/python3.12/site-packages/labelbox/data/annotation_types/label.py:61: UserWarning: Using TextData class for label.data is deprecated. Use a dict or an instance of GenericDataRowData instead.
#   warnings.warn(
# ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None)

# %%
annotations
# Out:
# [Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028k07yz7akn5y2i', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Klarna'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887029207yz4br4h6g5', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Henderson Storage'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor888029s07yzafyr2hqa', extra={}, keyframe=None, classifications=[])), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028407yzbiqy56tc', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Carrington Mortgage'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor888029q07yzd03icgsn', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Payless Power'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028a07yzf9ahbm5a', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Luckyland'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887029207yz4br4h6g5', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Stcu'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028207yzh26g3twi', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Snap Finance Payment'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor888029q07yzd03icgsn', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Southside Electric Cooperative'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028807yz2ibg357t', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Possible Finance'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028207yzh26g3twi', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Elklending'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028s07yz76mb0631', extra={}, keyframe=None, classifications=[])), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028c07yzc1b7gote', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Bigo Live'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028m07yz3bfu6qac', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='The Sauced Pig'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028a07yzf9ahbm5a', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Draftkings'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor888029q07yzd03icgsn', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Consolidated Communication'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887029207yz4br4h6g5', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Cleo'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028m07yz3bfu6qac', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Smokehouse Ii'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887029i07yz9qn5g700', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Racetrac'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887029i07yz9qn5g700', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Sheetz'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor888029q07yzd03icgsn', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Spectrum'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028i07yz1y7vcpyy', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='365 Markets'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887029207yz4br4h6g5', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Creditstrong Auscabank'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028c07yzc1b7gote', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Fatcats Austin'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028o07yz9zw1czy8', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Fingerhut Payments'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028s07yz76mb0631', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Rent A Center'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028807yz2ibg357t', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Stash'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028c07yzc1b7gote', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Distrokid Extras'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028207yzh26g3twi', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Cleo'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028207yzh26g3twi', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Brigit'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor888029q07yzd03icgsn', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Nv Energy'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028207yzh26g3twi', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Empower'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028w07yzb1vndzkh', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Cliffsnotes'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028w07yzb1vndzkh', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Anytime Fitness'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028m07yz3bfu6qac', extra={}, keyframe=None, classifications=[])), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028207yzh26g3twi', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Snap Finance Payment'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor888029q07yzd03icgsn', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='AT&T'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028c07yzc1b7gote', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Hulu'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor888029q07yzd03icgsn', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Spectrum'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor888029q07yzd03icgsn', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Inmate Phone Svc'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887029i07yz9qn5g700', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Holiday Station Store'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028o07yz9zw1czy8', extra={}, keyframe=None, classifications=[])), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028207yzh26g3twi', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='World Finance'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor888029q07yzd03icgsn', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Wessex Water'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028207yzh26g3twi', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Empower'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv024007vretepegws', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028407yzbiqy56tc', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Mr. Cooper Mortgage'), message_id=None)], extra={}),
# ...
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028a07yzf9ahbm5a', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Prizepicks'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028a07yzf9ahbm5a', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Fan Duel Sportsbook'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028a07yzf9ahbm5a', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='FanDuel'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028a07yzf9ahbm5a', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Prizepicks'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028a07yzf9ahbm5a', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Klar Gaming'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028c07yzc1b7gote', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='YouTube'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028w07yzb1vndzkh', extra={}, keyframe=None, classifications=[])), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028c07yzc1b7gote', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Amazon Kindle'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028a07yzf9ahbm5a', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Draftkings'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028a07yzf9ahbm5a', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Draftkings'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028y07yzfpkjaaf2', extra={}, keyframe=None, classifications=[])), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887029207yz4br4h6g5', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Patreon'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028c07yzc1b7gote', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Electronic Arts'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028c07yzc1b7gote', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Disney+'), message_id=None)], extra={}),
#  Label(uid=None, data=TextData(file_path=None,text=None,url=None), annotations=[ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhv023v07vr6rpy4psa', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv4rhw024607vrhnv4drsv', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor886027t07yz233m7w7k', extra={}, value=Radio(custom_metrics=None, confidence=None, answer=ClassificationAnswer(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltzor887028c07yzc1b7gote', extra={}, keyframe=None, classifications=[])), message_id=None), ClassificationAnnotation(custom_metrics=None, confidence=None, name=None, feature_schema_id='cltcv694m00vr07vt9957enwa', extra={}, value=Text(custom_metrics=None, confidence=None, answer='Peacock TV'), message_id=None)], extra={}),
#  ...]
